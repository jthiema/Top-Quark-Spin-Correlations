# %% [markdown]
# ## Make Minitree Tutorial
#
# Basic operations:
#
# Add a cell above by clicking on the blank space on the left of the cell then hit "a" once.<br>
# Add a cell below by clicking on the blank space on the left of the cell then hit "b" once.<br>
# Remove the cell by clicking on the blank space on the left of the cell then hit "d" twice.<br>
# To run the cell, click on the cell then hit "shift+enter".
#
# The first step is to import python libraries:

# %%
# scp the file events_000012600.root from T2 then run 

import uproot
import pandas
import argparse
import awkward as ak

# %% [markdown]
# Open a separate shell window, "scp" the file events_000012600.root from T2 then run. <br>
# ex. scp 'purdue_username'@hammer.rcac.purdue.edu:/mnt/hadoop/store/user/hyeonseo/mgp8_pp_tt012j_5f/events_000012600.root ~/CMS/FCC
#
# Move the .root file to the same folder as this tutorial. <br>
# ex. mv ~/events_000012600.root Top-Quark-Spin-Correlations/Tutorials/ <br>
# You need to specify the correct path to the file if you don't.
#
# Then import the .root data file:

# %%
file = uproot.open("events_000012600.root") # reads the file, you need to specify the correct path to the file
events = uproot.open("events_000012600.root:events;6") 

print(file.keys())
print(file.classnames())
print(file.values())
file["events;7"]
# Out:
# ['events;7', 'events;6', 'metadata;1']
# {'events;7': 'TTree', 'events;6': 'TTree', 'metadata;1': 'TTree'}
# [<TTree 'events' (472 branches) at 0x02a39c8372e0>, <TTree 'metadata' (2 branches) at 0x02a3ad272610>]
# <TTree 'events' (472 branches) at 0x02a39c8372e0>

# %% [markdown]
# Try out these commands for inspecting the data file: https://uproot.readthedocs.io/en/latest/basic.html <br>

# %% [markdown]
# ### Now define some functions that we will use later.

# %%
def deltaphi(e_phi, m_phi):
    d_phi = e_phi - m_phi
    if (d_phi > np.pi):
        d_phi -= 2*np.pi
    if (d_phi < -np.pi):
        d_phi += 2*np.pi
    return d_phi

def dR(e_phi, e_eta, m_phi, m_eta):
    d_eta = abs(e_eta - m_eta)
    d_phi = deltaphi(e_phi, m_phi)
    return np.sqrt(d_phi**2 + d_eta**2)

def CalcE(px,py,pz,m):
	E = np.sqrt(px**2 + py**2 + pz**2 + m**2)
	return E

# This function converts the cartesian momentum (as branch arrays) to pT, eta, phi coordinates
def ptetaphiarray(mass, px, py, pz, nevents):
    pt = []
    eta = []
    phi = []
    for i in range(nevents):
        if (i % 1000 == 0):
            print('Processing event ' + str(i) + ' of ' + str(nevents))
        pt.append([])
        eta.append([])
        phi.append([])
        for v in range(len(px[i])):
            pxi = px[i][v]
            pyi = py[i][v]
            pzi = pz[i][v]
            massi = mass[i][v]
            Ei = CalcE(pxi, pyi, pzi, massi)
            l  = ROOT.TLorentzVector()
            l.SetPxPyPzE(pxi, pyi, pzi, Ei)
            pti = l.Pt()
            phii = l.Phi()
            etai = l.Eta()
            pt[i].append(pti)
            eta[i].append(etai)
            phi[i].append(phii)
    return (ak.Array(pt), ak.Array(eta), ak.Array(phi))

# %%
events.keys()
# Out:
# ['mePsMatchingVars',
#  'mePsMatchingVars/mePsMatchingVars.value',
#  'mcEventWeights',
#  'mcEventWeights/mcEventWeights.value',
#  'skimmedGenParticles',
#  'skimmedGenParticles/skimmedGenParticles.core.bits',
#  'skimmedGenParticles/skimmedGenParticles.core.charge',
#  'skimmedGenParticles/skimmedGenParticles.core.p4.mass',
#  'skimmedGenParticles/skimmedGenParticles.core.p4.px',
#  'skimmedGenParticles/skimmedGenParticles.core.p4.py',
#  'skimmedGenParticles/skimmedGenParticles.core.p4.pz',
#  'skimmedGenParticles/skimmedGenParticles.core.pdgId',
#  'skimmedGenParticles/skimmedGenParticles.core.status',
#  'skimmedGenParticles/skimmedGenParticles.core.vertex.x',
#  'skimmedGenParticles/skimmedGenParticles.core.vertex.y',
#  'skimmedGenParticles/skimmedGenParticles.core.vertex.z',
#  'skimmedGenParticles#0',
#  'skimmedGenParticles#0/skimmedGenParticles#0.index',
#  'skimmedGenParticles#0/skimmedGenParticles#0.collectionID',
#  'skimmedGenParticles#1',
#  'skimmedGenParticles#1/skimmedGenParticles#1.index',
#  'skimmedGenParticles#1/skimmedGenParticles#1.collectionID',
#  'muons',
#  'muons/muons.core.bits',
#  'muons/muons.core.charge',
#  'muons/muons.core.p4.mass',
#  'muons/muons.core.p4.px',
#  'muons/muons.core.p4.py',
#  'muons/muons.core.p4.pz',
#  'muons/muons.core.pdgId',
#  'muons/muons.core.status',
#  'muons/muons.core.vertex.x',
#  'muons/muons.core.vertex.y',
#  'muons/muons.core.vertex.z',
#  'muons/muons.tracks_begin',
#  'muons/muons.tracks_end',
#  'muons/muons.clusters_begin',
#  'muons/muons.clusters_end',
#  'muons#0',
#  'muons#0/muons#0.index',
#  'muons#0/muons#0.collectionID',
#  'muons#1',
#  'muons#1/muons#1.index',
#  'muons#1/muons#1.collectionID',
#  'muonsToMC',
#  'muonsToMC#0',
#  'muonsToMC#0/muonsToMC#0.index',
#  'muonsToMC#0/muonsToMC#0.collectionID',
#  'muonsToMC#1',
#  'muonsToMC#1/muonsToMC#1.index',
#  'muonsToMC#1/muonsToMC#1.collectionID',
#  'muonITags',
#  'muonITags/muonITags.tag',
#  'muonITags#0',
#  'muonITags#0/muonITags#0.index',
#  'muonITags#0/muonITags#0.collectionID',
#  'electrons',
#  'electrons/electrons.core.bits',
#  'electrons/electrons.core.charge',
#  'electrons/electrons.core.p4.mass',
#  'electrons/electrons.core.p4.px',
#  'electrons/electrons.core.p4.py',
#  'electrons/electrons.core.p4.pz',
#  'electrons/electrons.core.pdgId',
#  'electrons/electrons.core.status',
#  'electrons/electrons.core.vertex.x',
#  'electrons/electrons.core.vertex.y',
#  'electrons/electrons.core.vertex.z',
#  'electrons/electrons.tracks_begin',
#  'electrons/electrons.tracks_end',
#  'electrons/electrons.clusters_begin',
#  'electrons/electrons.clusters_end',
#  'electrons#0',
#  'electrons#0/electrons#0.index',
#  'electrons#0/electrons#0.collectionID',
#  'electrons#1',
#  'electrons#1/electrons#1.index',
#  'electrons#1/electrons#1.collectionID',
#  'electronsToMC',
#  'electronsToMC#0',
#  'electronsToMC#0/electronsToMC#0.index',
#  'electronsToMC#0/electronsToMC#0.collectionID',
#  'electronsToMC#1',
#  'electronsToMC#1/electronsToMC#1.index',
#  'electronsToMC#1/electronsToMC#1.collectionID',
#  'electronITags',
#  'electronITags/electronITags.tag',
#  'electronITags#0',
#  'electronITags#0/electronITags#0.index',
#  'electronITags#0/electronITags#0.collectionID',
#  'photons',
#  'photons/photons.core.bits',
#  'photons/photons.core.charge',
#  'photons/photons.core.p4.mass',
#  'photons/photons.core.p4.px',
#  'photons/photons.core.p4.py',
#  'photons/photons.core.p4.pz',
#  'photons/photons.core.pdgId',
#  'photons/photons.core.status',
#  'photons/photons.core.vertex.x',
#  'photons/photons.core.vertex.y',
#  'photons/photons.core.vertex.z',
#  'photons/photons.tracks_begin',
#  'photons/photons.tracks_end',
#  'photons/photons.clusters_begin',
#  'photons/photons.clusters_end',
#  'photons#0',
#  'photons#0/photons#0.index',
#  'photons#0/photons#0.collectionID',
#  'photons#1',
#  'photons#1/photons#1.index',
#  'photons#1/photons#1.collectionID',
#  'photonsToMC',
#  'photonsToMC#0',
#  'photonsToMC#0/photonsToMC#0.index',
#  'photonsToMC#0/photonsToMC#0.collectionID',
#  'photonsToMC#1',
#  'photonsToMC#1/photonsToMC#1.index',
#  'photonsToMC#1/photonsToMC#1.collectionID',
#  'photonITags',
#  'photonITags/photonITags.tag',
#  'photonITags#0',
#  'photonITags#0/photonITags#0.index',
#  'photonITags#0/photonITags#0.collectionID',
#  'pfcharged',
#  'pfcharged/pfcharged.core.bits',
#  'pfcharged/pfcharged.core.charge',
#  'pfcharged/pfcharged.core.p4.mass',
#  'pfcharged/pfcharged.core.p4.px',
#  'pfcharged/pfcharged.core.p4.py',
#  'pfcharged/pfcharged.core.p4.pz',
#  'pfcharged/pfcharged.core.pdgId',
#  'pfcharged/pfcharged.core.status',
#  'pfcharged/pfcharged.core.vertex.x',
#  'pfcharged/pfcharged.core.vertex.y',
#  'pfcharged/pfcharged.core.vertex.z',
#  'pfcharged/pfcharged.tracks_begin',
#  'pfcharged/pfcharged.tracks_end',
#  'pfcharged/pfcharged.clusters_begin',
#  'pfcharged/pfcharged.clusters_end',
#  'pfcharged#0',
#  'pfcharged#0/pfcharged#0.index',
#  'pfcharged#0/pfcharged#0.collectionID',
#  'pfcharged#1',
#  'pfcharged#1/pfcharged#1.index',
#  'pfcharged#1/pfcharged#1.collectionID',
#  'chargedToMC',
#  'chargedToMC#0',
#  'chargedToMC#0/chargedToMC#0.index',
#  'chargedToMC#0/chargedToMC#0.collectionID',
#  'chargedToMC#1',
#  'chargedToMC#1/chargedToMC#1.index',
#  'chargedToMC#1/chargedToMC#1.collectionID',
#  'pfphotons',
#  'pfphotons/pfphotons.core.bits',
#  'pfphotons/pfphotons.core.charge',
#  'pfphotons/pfphotons.core.p4.mass',
#  'pfphotons/pfphotons.core.p4.px',
#  'pfphotons/pfphotons.core.p4.py',
#  'pfphotons/pfphotons.core.p4.pz',
#  'pfphotons/pfphotons.core.pdgId',
#  'pfphotons/pfphotons.core.status',
#  'pfphotons/pfphotons.core.vertex.x',
#  'pfphotons/pfphotons.core.vertex.y',
#  'pfphotons/pfphotons.core.vertex.z',
#  'pfphotons/pfphotons.tracks_begin',
#  'pfphotons/pfphotons.tracks_end',
#  'pfphotons/pfphotons.clusters_begin',
#  'pfphotons/pfphotons.clusters_end',
#  'pfphotons#0',
#  'pfphotons#0/pfphotons#0.index',
#  'pfphotons#0/pfphotons#0.collectionID',
#  'pfphotons#1',
#  'pfphotons#1/pfphotons#1.index',
#  'pfphotons#1/pfphotons#1.collectionID',
#  'pfphotonsToMC',
#  'pfphotonsToMC#0',
#  'pfphotonsToMC#0/pfphotonsToMC#0.index',
#  'pfphotonsToMC#0/pfphotonsToMC#0.collectionID',
#  'pfphotonsToMC#1',
#  'pfphotonsToMC#1/pfphotonsToMC#1.index',
#  'pfphotonsToMC#1/pfphotonsToMC#1.collectionID',
#  'pfneutrals',
#  'pfneutrals/pfneutrals.core.bits',
#  'pfneutrals/pfneutrals.core.charge',
#  'pfneutrals/pfneutrals.core.p4.mass',
#  'pfneutrals/pfneutrals.core.p4.px',
#  'pfneutrals/pfneutrals.core.p4.py',
#  'pfneutrals/pfneutrals.core.p4.pz',
#  'pfneutrals/pfneutrals.core.pdgId',
#  'pfneutrals/pfneutrals.core.status',
#  'pfneutrals/pfneutrals.core.vertex.x',
#  'pfneutrals/pfneutrals.core.vertex.y',
#  'pfneutrals/pfneutrals.core.vertex.z',
#  'pfneutrals/pfneutrals.tracks_begin',
#  'pfneutrals/pfneutrals.tracks_end',
#  'pfneutrals/pfneutrals.clusters_begin',
#  'pfneutrals/pfneutrals.clusters_end',
#  'pfneutrals#0',
#  'pfneutrals#0/pfneutrals#0.index',
#  'pfneutrals#0/pfneutrals#0.collectionID',
#  'pfneutrals#1',
#  'pfneutrals#1/pfneutrals#1.index',
#  'pfneutrals#1/pfneutrals#1.collectionID',
#  'pfneutralsToMC',
#  'pfneutralsToMC#0',
#  'pfneutralsToMC#0/pfneutralsToMC#0.index',
#  'pfneutralsToMC#0/pfneutralsToMC#0.collectionID',
#  'pfneutralsToMC#1',
#  'pfneutralsToMC#1/pfneutralsToMC#1.index',
#  'pfneutralsToMC#1/pfneutralsToMC#1.collectionID',
#  'genjets02',
#  'genjets02/genjets02.core.area',
#  'genjets02/genjets02.core.bits',
#  'genjets02/genjets02.core.p4.mass',
#  'genjets02/genjets02.core.p4.px',
#  'genjets02/genjets02.core.p4.py',
#  'genjets02/genjets02.core.p4.pz',
#  'genjets02/genjets02.particles_begin',
#  'genjets02/genjets02.particles_end',
#  'genjets02#0',
#  'genjets02#0/genjets02#0.index',
#  'genjets02#0/genjets02#0.collectionID',
#  'genjetsFlavor02',
#  'genjetsFlavor02/genjetsFlavor02.tag',
#  'genjetsFlavor02#0',
#  'genjetsFlavor02#0/genjetsFlavor02#0.index',
#  'genjetsFlavor02#0/genjetsFlavor02#0.collectionID',
#  'genjets04',
#  'genjets04/genjets04.core.area',
#  'genjets04/genjets04.core.bits',
#  'genjets04/genjets04.core.p4.mass',
#  'genjets04/genjets04.core.p4.px',
#  'genjets04/genjets04.core.p4.py',
#  'genjets04/genjets04.core.p4.pz',
#  'genjets04/genjets04.particles_begin',
#  'genjets04/genjets04.particles_end',
#  'genjets04#0',
#  'genjets04#0/genjets04#0.index',
#  'genjets04#0/genjets04#0.collectionID',
#  'genjetsFlavor04',
#  'genjetsFlavor04/genjetsFlavor04.tag',
#  'genjetsFlavor04#0',
#  'genjetsFlavor04#0/genjetsFlavor04#0.index',
#  'genjetsFlavor04#0/genjetsFlavor04#0.collectionID',
#  'genjets08',
#  'genjets08/genjets08.core.area',
#  'genjets08/genjets08.core.bits',
#  'genjets08/genjets08.core.p4.mass',
#  'genjets08/genjets08.core.p4.px',
#  'genjets08/genjets08.core.p4.py',
#  'genjets08/genjets08.core.p4.pz',
#  'genjets08/genjets08.particles_begin',
#  'genjets08/genjets08.particles_end',
#  'genjets08#0',
#  'genjets08#0/genjets08#0.index',
#  'genjets08#0/genjets08#0.collectionID',
#  'genjetsFlavor08',
#  'genjetsFlavor08/genjetsFlavor08.tag',
#  'genjetsFlavor08#0',
#  'genjetsFlavor08#0/genjetsFlavor08#0.index',
#  'genjetsFlavor08#0/genjetsFlavor08#0.collectionID',
#  'genjets15',
#  'genjets15/genjets15.core.area',
#  'genjets15/genjets15.core.bits',
#  'genjets15/genjets15.core.p4.mass',
#  'genjets15/genjets15.core.p4.px',
#  'genjets15/genjets15.core.p4.py',
#  'genjets15/genjets15.core.p4.pz',
#  'genjets15/genjets15.particles_begin',
#  'genjets15/genjets15.particles_end',
#  'genjets15#0',
#  'genjets15#0/genjets15#0.index',
#  'genjets15#0/genjets15#0.collectionID',
#  'genjetsFlavor15',
#  'genjetsFlavor15/genjetsFlavor15.tag',
#  'genjetsFlavor15#0',
#  'genjetsFlavor15#0/genjetsFlavor15#0.index',
#  'genjetsFlavor15#0/genjetsFlavor15#0.collectionID',
#  'calojets02',
#  'calojets02/calojets02.core.area',
#  'calojets02/calojets02.core.bits',
#  'calojets02/calojets02.core.p4.mass',
#  'calojets02/calojets02.core.p4.px',
#  'calojets02/calojets02.core.p4.py',
#  'calojets02/calojets02.core.p4.pz',
#  'calojets02/calojets02.particles_begin',
#  'calojets02/calojets02.particles_end',
#  'calojets02#0',
#  'calojets02#0/calojets02#0.index',
#  'calojets02#0/calojets02#0.collectionID',
#  'calojetsFlavor02',
#  'calojetsFlavor02/calojetsFlavor02.tag',
#  'calojetsFlavor02#0',
#  'calojetsFlavor02#0/calojetsFlavor02#0.index',
#  'calojetsFlavor02#0/calojetsFlavor02#0.collectionID',
#  'calobTags02',
#  'calobTags02/calobTags02.tag',
#  'calobTags02#0',
#  'calobTags02#0/calobTags02#0.index',
#  'calobTags02#0/calobTags02#0.collectionID',
#  'calocTags02',
#  'calocTags02/calocTags02.tag',
#  'calocTags02#0',
#  'calocTags02#0/calocTags02#0.index',
#  'calocTags02#0/calocTags02#0.collectionID',
#  'calotauTags02',
#  'calotauTags02/calotauTags02.tag',
#  'calotauTags02#0',
#  'calotauTags02#0/calotauTags02#0.index',
#  'calotauTags02#0/calotauTags02#0.collectionID',
#  'calojetParts02',
#  'calojetParts02/calojetParts02.core.bits',
#  'calojetParts02/calojetParts02.core.charge',
#  'calojetParts02/calojetParts02.core.p4.mass',
#  'calojetParts02/calojetParts02.core.p4.px',
#  'calojetParts02/calojetParts02.core.p4.py',
#  'calojetParts02/calojetParts02.core.p4.pz',
#  'calojetParts02/calojetParts02.core.pdgId',
#  'calojetParts02/calojetParts02.core.status',
#  'calojetParts02/calojetParts02.core.vertex.x',
#  'calojetParts02/calojetParts02.core.vertex.y',
#  'calojetParts02/calojetParts02.core.vertex.z',
#  'calojetParts02/calojetParts02.tracks_begin',
#  'calojetParts02/calojetParts02.tracks_end',
#  'calojetParts02/calojetParts02.clusters_begin',
#  'calojetParts02/calojetParts02.clusters_end',
#  'calojetParts02#0',
#  'calojetParts02#0/calojetParts02#0.index',
#  'calojetParts02#0/calojetParts02#0.collectionID',
#  'calojetParts02#1',
#  'calojetParts02#1/calojetParts02#1.index',
#  'calojetParts02#1/calojetParts02#1.collectionID',
#  'calojetsOneSubJettiness02',
#  'calojetsOneSubJettiness02/calojetsOneSubJettiness02.tag',
#  'calojetsOneSubJettiness02#0',
#  'calojetsOneSubJettiness02#0/calojetsOneSubJettiness02#0.index',
#  'calojetsOneSubJettiness02#0/calojetsOneSubJettiness02#0.collectionID',
#  'calojetsTwoSubJettiness02',
#  'calojetsTwoSubJettiness02/calojetsTwoSubJettiness02.tag',
#  'calojetsTwoSubJettiness02#0',
#  'calojetsTwoSubJettiness02#0/calojetsTwoSubJettiness02#0.index',
#  'calojetsTwoSubJettiness02#0/calojetsTwoSubJettiness02#0.collectionID',
#  'calojetsThreeSubJettiness02',
#  'calojetsThreeSubJettiness02/calojetsThreeSubJettiness02.tag',
#  'calojetsThreeSubJettiness02#0',
#  'calojetsThreeSubJettiness02#0/calojetsThreeSubJettiness02#0.index',
#  'calojetsThreeSubJettiness02#0/calojetsThreeSubJettiness02#0.collectionID',
#  'calosubjetsTrimmingTagged02',
#  'calosubjetsTrimmingTagged02/calosubjetsTrimmingTagged02.subjets_begin',
#  'calosubjetsTrimmingTagged02/calosubjetsTrimmingTagged02.subjets_end',
#  'calosubjetsTrimmingTagged02#0',
#  'calosubjetsTrimmingTagged02#0/calosubjetsTrimmingTagged02#0.index',
#  'calosubjetsTrimmingTagged02#0/calosubjetsTrimmingTagged02#0.collectionID',
#  'calosubjetsTrimmingTagged02#1',
#  'calosubjetsTrimmingTagged02#1/calosubjetsTrimmingTagged02#1.index',
#  'calosubjetsTrimmingTagged02#1/calosubjetsTrimmingTagged02#1.collectionID',
#  'calosubjetsPruningTagged02',
#  'calosubjetsPruningTagged02/calosubjetsPruningTagged02.subjets_begin',
#  'calosubjetsPruningTagged02/calosubjetsPruningTagged02.subjets_end',
#  'calosubjetsPruningTagged02#0',
#  'calosubjetsPruningTagged02#0/calosubjetsPruningTagged02#0.index',
#  'calosubjetsPruningTagged02#0/calosubjetsPruningTagged02#0.collectionID',
#  'calosubjetsPruningTagged02#1',
#  'calosubjetsPruningTagged02#1/calosubjetsPruningTagged02#1.index',
#  'calosubjetsPruningTagged02#1/calosubjetsPruningTagged02#1.collectionID',
#  'calosubjetsSoftDropTagged02',
#  'calosubjetsSoftDropTagged02/calosubjetsSoftDropTagged02.subjets_begin',
#  'calosubjetsSoftDropTagged02/calosubjetsSoftDropTagged02.subjets_end',
#  'calosubjetsSoftDropTagged02#0',
#  'calosubjetsSoftDropTagged02#0/calosubjetsSoftDropTagged02#0.index',
#  'calosubjetsSoftDropTagged02#0/calosubjetsSoftDropTagged02#0.collectionID',
#  'calosubjetsSoftDropTagged02#1',
#  'calosubjetsSoftDropTagged02#1/calosubjetsSoftDropTagged02#1.index',
#  'calosubjetsSoftDropTagged02#1/calosubjetsSoftDropTagged02#1.collectionID',
#  'calosubjetsTrimming02',
#  'calosubjetsTrimming02/calosubjetsTrimming02.core.area',
#  'calosubjetsTrimming02/calosubjetsTrimming02.core.bits',
#  'calosubjetsTrimming02/calosubjetsTrimming02.core.p4.mass',
#  'calosubjetsTrimming02/calosubjetsTrimming02.core.p4.px',
#  'calosubjetsTrimming02/calosubjetsTrimming02.core.p4.py',
#  'calosubjetsTrimming02/calosubjetsTrimming02.core.p4.pz',
#  'calosubjetsTrimming02/calosubjetsTrimming02.particles_begin',
#  'calosubjetsTrimming02/calosubjetsTrimming02.particles_end',
#  'calosubjetsTrimming02#0',
#  'calosubjetsTrimming02#0/calosubjetsTrimming02#0.index',
#  'calosubjetsTrimming02#0/calosubjetsTrimming02#0.collectionID',
#  'calosubjetsPruning02',
#  'calosubjetsPruning02/calosubjetsPruning02.core.area',
#  'calosubjetsPruning02/calosubjetsPruning02.core.bits',
#  'calosubjetsPruning02/calosubjetsPruning02.core.p4.mass',
#  'calosubjetsPruning02/calosubjetsPruning02.core.p4.px',
#  'calosubjetsPruning02/calosubjetsPruning02.core.p4.py',
#  'calosubjetsPruning02/calosubjetsPruning02.core.p4.pz',
#  'calosubjetsPruning02/calosubjetsPruning02.particles_begin',
#  'calosubjetsPruning02/calosubjetsPruning02.particles_end',
#  'calosubjetsPruning02#0',
#  'calosubjetsPruning02#0/calosubjetsPruning02#0.index',
#  'calosubjetsPruning02#0/calosubjetsPruning02#0.collectionID',
#  'calosubjetsSoftDrop02',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.core.area',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.core.bits',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.core.p4.mass',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.core.p4.px',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.core.p4.py',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.core.p4.pz',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.particles_begin',
#  'calosubjetsSoftDrop02/calosubjetsSoftDrop02.particles_end',
#  'calosubjetsSoftDrop02#0',
#  'calosubjetsSoftDrop02#0/calosubjetsSoftDrop02#0.index',
#  'calosubjetsSoftDrop02#0/calosubjetsSoftDrop02#0.collectionID',
#  'calojets04',
#  'calojets04/calojets04.core.area',
#  'calojets04/calojets04.core.bits',
#  'calojets04/calojets04.core.p4.mass',
#  'calojets04/calojets04.core.p4.px',
#  'calojets04/calojets04.core.p4.py',
#  'calojets04/calojets04.core.p4.pz',
#  'calojets04/calojets04.particles_begin',
#  'calojets04/calojets04.particles_end',
#  'calojets04#0',
#  'calojets04#0/calojets04#0.index',
#  'calojets04#0/calojets04#0.collectionID',
#  'calojetsFlavor04',
#  'calojetsFlavor04/calojetsFlavor04.tag',
#  'calojetsFlavor04#0',
#  'calojetsFlavor04#0/calojetsFlavor04#0.index',
#  'calojetsFlavor04#0/calojetsFlavor04#0.collectionID',
#  'calobTags04',
#  'calobTags04/calobTags04.tag',
#  'calobTags04#0',
#  'calobTags04#0/calobTags04#0.index',
#  'calobTags04#0/calobTags04#0.collectionID',
#  'calocTags04',
#  'calocTags04/calocTags04.tag',
#  'calocTags04#0',
#  'calocTags04#0/calocTags04#0.index',
#  'calocTags04#0/calocTags04#0.collectionID',
#  'calotauTags04',
#  'calotauTags04/calotauTags04.tag',
#  'calotauTags04#0',
#  'calotauTags04#0/calotauTags04#0.index',
#  'calotauTags04#0/calotauTags04#0.collectionID',
#  'calojetParts04',
#  'calojetParts04/calojetParts04.core.bits',
#  'calojetParts04/calojetParts04.core.charge',
#  'calojetParts04/calojetParts04.core.p4.mass',
#  'calojetParts04/calojetParts04.core.p4.px',
#  'calojetParts04/calojetParts04.core.p4.py',
#  'calojetParts04/calojetParts04.core.p4.pz',
#  'calojetParts04/calojetParts04.core.pdgId',
#  'calojetParts04/calojetParts04.core.status',
#  'calojetParts04/calojetParts04.core.vertex.x',
#  'calojetParts04/calojetParts04.core.vertex.y',
#  'calojetParts04/calojetParts04.core.vertex.z',
#  'calojetParts04/calojetParts04.tracks_begin',
#  'calojetParts04/calojetParts04.tracks_end',
#  'calojetParts04/calojetParts04.clusters_begin',
#  'calojetParts04/calojetParts04.clusters_end',
#  'calojetParts04#0',
#  'calojetParts04#0/calojetParts04#0.index',
#  'calojetParts04#0/calojetParts04#0.collectionID',
#  'calojetParts04#1',
#  'calojetParts04#1/calojetParts04#1.index',
#  'calojetParts04#1/calojetParts04#1.collectionID',
#  'calojetsOneSubJettiness04',
#  'calojetsOneSubJettiness04/calojetsOneSubJettiness04.tag',
#  'calojetsOneSubJettiness04#0',
#  'calojetsOneSubJettiness04#0/calojetsOneSubJettiness04#0.index',
#  'calojetsOneSubJettiness04#0/calojetsOneSubJettiness04#0.collectionID',
#  'calojetsTwoSubJettiness04',
#  'calojetsTwoSubJettiness04/calojetsTwoSubJettiness04.tag',
#  'calojetsTwoSubJettiness04#0',
#  'calojetsTwoSubJettiness04#0/calojetsTwoSubJettiness04#0.index',
#  'calojetsTwoSubJettiness04#0/calojetsTwoSubJettiness04#0.collectionID',
#  'calojetsThreeSubJettiness04',
#  'calojetsThreeSubJettiness04/calojetsThreeSubJettiness04.tag',
#  'calojetsThreeSubJettiness04#0',
#  'calojetsThreeSubJettiness04#0/calojetsThreeSubJettiness04#0.index',
#  'calojetsThreeSubJettiness04#0/calojetsThreeSubJettiness04#0.collectionID',
#  'calosubjetsTrimmingTagged04',
#  'calosubjetsTrimmingTagged04/calosubjetsTrimmingTagged04.subjets_begin',
#  'calosubjetsTrimmingTagged04/calosubjetsTrimmingTagged04.subjets_end',
#  'calosubjetsTrimmingTagged04#0',
#  'calosubjetsTrimmingTagged04#0/calosubjetsTrimmingTagged04#0.index',
#  'calosubjetsTrimmingTagged04#0/calosubjetsTrimmingTagged04#0.collectionID',
#  'calosubjetsTrimmingTagged04#1',
#  'calosubjetsTrimmingTagged04#1/calosubjetsTrimmingTagged04#1.index',
#  'calosubjetsTrimmingTagged04#1/calosubjetsTrimmingTagged04#1.collectionID',
#  'calosubjetsPruningTagged04',
#  'calosubjetsPruningTagged04/calosubjetsPruningTagged04.subjets_begin',
#  'calosubjetsPruningTagged04/calosubjetsPruningTagged04.subjets_end',
#  'calosubjetsPruningTagged04#0',
#  'calosubjetsPruningTagged04#0/calosubjetsPruningTagged04#0.index',
#  'calosubjetsPruningTagged04#0/calosubjetsPruningTagged04#0.collectionID',
#  'calosubjetsPruningTagged04#1',
#  'calosubjetsPruningTagged04#1/calosubjetsPruningTagged04#1.index',
#  'calosubjetsPruningTagged04#1/calosubjetsPruningTagged04#1.collectionID',
#  'calosubjetsSoftDropTagged04',
#  'calosubjetsSoftDropTagged04/calosubjetsSoftDropTagged04.subjets_begin',
#  'calosubjetsSoftDropTagged04/calosubjetsSoftDropTagged04.subjets_end',
#  'calosubjetsSoftDropTagged04#0',
#  'calosubjetsSoftDropTagged04#0/calosubjetsSoftDropTagged04#0.index',
#  'calosubjetsSoftDropTagged04#0/calosubjetsSoftDropTagged04#0.collectionID',
#  'calosubjetsSoftDropTagged04#1',
#  'calosubjetsSoftDropTagged04#1/calosubjetsSoftDropTagged04#1.index',
#  'calosubjetsSoftDropTagged04#1/calosubjetsSoftDropTagged04#1.collectionID',
#  'calosubjetsTrimming04',
#  'calosubjetsTrimming04/calosubjetsTrimming04.core.area',
#  'calosubjetsTrimming04/calosubjetsTrimming04.core.bits',
#  'calosubjetsTrimming04/calosubjetsTrimming04.core.p4.mass',
#  'calosubjetsTrimming04/calosubjetsTrimming04.core.p4.px',
#  'calosubjetsTrimming04/calosubjetsTrimming04.core.p4.py',
#  'calosubjetsTrimming04/calosubjetsTrimming04.core.p4.pz',
#  'calosubjetsTrimming04/calosubjetsTrimming04.particles_begin',
#  'calosubjetsTrimming04/calosubjetsTrimming04.particles_end',
#  'calosubjetsTrimming04#0',
#  'calosubjetsTrimming04#0/calosubjetsTrimming04#0.index',
#  'calosubjetsTrimming04#0/calosubjetsTrimming04#0.collectionID',
#  'calosubjetsPruning04',
#  'calosubjetsPruning04/calosubjetsPruning04.core.area',
#  'calosubjetsPruning04/calosubjetsPruning04.core.bits',
#  'calosubjetsPruning04/calosubjetsPruning04.core.p4.mass',
#  'calosubjetsPruning04/calosubjetsPruning04.core.p4.px',
#  'calosubjetsPruning04/calosubjetsPruning04.core.p4.py',
#  'calosubjetsPruning04/calosubjetsPruning04.core.p4.pz',
#  'calosubjetsPruning04/calosubjetsPruning04.particles_begin',
#  'calosubjetsPruning04/calosubjetsPruning04.particles_end',
#  'calosubjetsPruning04#0',
#  'calosubjetsPruning04#0/calosubjetsPruning04#0.index',
#  'calosubjetsPruning04#0/calosubjetsPruning04#0.collectionID',
#  'calosubjetsSoftDrop04',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.core.area',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.core.bits',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.core.p4.mass',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.core.p4.px',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.core.p4.py',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.core.p4.pz',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.particles_begin',
#  'calosubjetsSoftDrop04/calosubjetsSoftDrop04.particles_end',
#  'calosubjetsSoftDrop04#0',
#  'calosubjetsSoftDrop04#0/calosubjetsSoftDrop04#0.index',
#  'calosubjetsSoftDrop04#0/calosubjetsSoftDrop04#0.collectionID',
#  'calojets08',
#  'calojets08/calojets08.core.area',
#  'calojets08/calojets08.core.bits',
#  'calojets08/calojets08.core.p4.mass',
#  'calojets08/calojets08.core.p4.px',
#  'calojets08/calojets08.core.p4.py',
#  'calojets08/calojets08.core.p4.pz',
#  'calojets08/calojets08.particles_begin',
#  'calojets08/calojets08.particles_end',
#  'calojets08#0',
#  'calojets08#0/calojets08#0.index',
#  'calojets08#0/calojets08#0.collectionID',
#  'calojetsFlavor08',
#  'calojetsFlavor08/calojetsFlavor08.tag',
#  'calojetsFlavor08#0',
#  'calojetsFlavor08#0/calojetsFlavor08#0.index',
#  'calojetsFlavor08#0/calojetsFlavor08#0.collectionID',
#  'calobTags08',
#  'calobTags08/calobTags08.tag',
#  'calobTags08#0',
#  'calobTags08#0/calobTags08#0.index',
#  'calobTags08#0/calobTags08#0.collectionID',
#  'calocTags08',
#  'calocTags08/calocTags08.tag',
#  'calocTags08#0',
#  'calocTags08#0/calocTags08#0.index',
#  'calocTags08#0/calocTags08#0.collectionID',
#  'calotauTags08',
#  'calotauTags08/calotauTags08.tag',
#  'calotauTags08#0',
#  'calotauTags08#0/calotauTags08#0.index',
#  'calotauTags08#0/calotauTags08#0.collectionID',
#  'calojetParts08',
#  'calojetParts08/calojetParts08.core.bits',
#  'calojetParts08/calojetParts08.core.charge',
#  'calojetParts08/calojetParts08.core.p4.mass',
#  'calojetParts08/calojetParts08.core.p4.px',
#  'calojetParts08/calojetParts08.core.p4.py',
#  'calojetParts08/calojetParts08.core.p4.pz',
#  'calojetParts08/calojetParts08.core.pdgId',
#  'calojetParts08/calojetParts08.core.status',
#  'calojetParts08/calojetParts08.core.vertex.x',
#  'calojetParts08/calojetParts08.core.vertex.y',
#  'calojetParts08/calojetParts08.core.vertex.z',
#  'calojetParts08/calojetParts08.tracks_begin',
#  'calojetParts08/calojetParts08.tracks_end',
#  'calojetParts08/calojetParts08.clusters_begin',
#  'calojetParts08/calojetParts08.clusters_end',
#  'calojetParts08#0',
#  'calojetParts08#0/calojetParts08#0.index',
#  'calojetParts08#0/calojetParts08#0.collectionID',
#  'calojetParts08#1',
#  'calojetParts08#1/calojetParts08#1.index',
#  'calojetParts08#1/calojetParts08#1.collectionID',
#  'calojetsOneSubJettiness08',
#  'calojetsOneSubJettiness08/calojetsOneSubJettiness08.tag',
#  'calojetsOneSubJettiness08#0',
#  'calojetsOneSubJettiness08#0/calojetsOneSubJettiness08#0.index',
#  'calojetsOneSubJettiness08#0/calojetsOneSubJettiness08#0.collectionID',
#  'calojetsTwoSubJettiness08',
#  'calojetsTwoSubJettiness08/calojetsTwoSubJettiness08.tag',
#  'calojetsTwoSubJettiness08#0',
#  'calojetsTwoSubJettiness08#0/calojetsTwoSubJettiness08#0.index',
#  'calojetsTwoSubJettiness08#0/calojetsTwoSubJettiness08#0.collectionID',
#  'calojetsThreeSubJettiness08',
#  'calojetsThreeSubJettiness08/calojetsThreeSubJettiness08.tag',
#  'calojetsThreeSubJettiness08#0',
#  'calojetsThreeSubJettiness08#0/calojetsThreeSubJettiness08#0.index',
#  'calojetsThreeSubJettiness08#0/calojetsThreeSubJettiness08#0.collectionID',
#  'calosubjetsTrimmingTagged08',
#  'calosubjetsTrimmingTagged08/calosubjetsTrimmingTagged08.subjets_begin',
#  'calosubjetsTrimmingTagged08/calosubjetsTrimmingTagged08.subjets_end',
#  'calosubjetsTrimmingTagged08#0',
#  'calosubjetsTrimmingTagged08#0/calosubjetsTrimmingTagged08#0.index',
#  'calosubjetsTrimmingTagged08#0/calosubjetsTrimmingTagged08#0.collectionID',
#  'calosubjetsTrimmingTagged08#1',
#  'calosubjetsTrimmingTagged08#1/calosubjetsTrimmingTagged08#1.index',
#  'calosubjetsTrimmingTagged08#1/calosubjetsTrimmingTagged08#1.collectionID',
#  'calosubjetsPruningTagged08',
#  'calosubjetsPruningTagged08/calosubjetsPruningTagged08.subjets_begin',
#  'calosubjetsPruningTagged08/calosubjetsPruningTagged08.subjets_end',
#  'calosubjetsPruningTagged08#0',
#  'calosubjetsPruningTagged08#0/calosubjetsPruningTagged08#0.index',
#  'calosubjetsPruningTagged08#0/calosubjetsPruningTagged08#0.collectionID',
#  'calosubjetsPruningTagged08#1',
#  'calosubjetsPruningTagged08#1/calosubjetsPruningTagged08#1.index',
#  'calosubjetsPruningTagged08#1/calosubjetsPruningTagged08#1.collectionID',
#  'calosubjetsSoftDropTagged08',
#  'calosubjetsSoftDropTagged08/calosubjetsSoftDropTagged08.subjets_begin',
#  'calosubjetsSoftDropTagged08/calosubjetsSoftDropTagged08.subjets_end',
#  'calosubjetsSoftDropTagged08#0',
#  'calosubjetsSoftDropTagged08#0/calosubjetsSoftDropTagged08#0.index',
#  'calosubjetsSoftDropTagged08#0/calosubjetsSoftDropTagged08#0.collectionID',
#  'calosubjetsSoftDropTagged08#1',
#  'calosubjetsSoftDropTagged08#1/calosubjetsSoftDropTagged08#1.index',
#  'calosubjetsSoftDropTagged08#1/calosubjetsSoftDropTagged08#1.collectionID',
#  'calosubjetsTrimming08',
#  'calosubjetsTrimming08/calosubjetsTrimming08.core.area',
#  'calosubjetsTrimming08/calosubjetsTrimming08.core.bits',
#  'calosubjetsTrimming08/calosubjetsTrimming08.core.p4.mass',
#  'calosubjetsTrimming08/calosubjetsTrimming08.core.p4.px',
#  'calosubjetsTrimming08/calosubjetsTrimming08.core.p4.py',
#  'calosubjetsTrimming08/calosubjetsTrimming08.core.p4.pz',
#  'calosubjetsTrimming08/calosubjetsTrimming08.particles_begin',
#  'calosubjetsTrimming08/calosubjetsTrimming08.particles_end',
#  'calosubjetsTrimming08#0',
#  'calosubjetsTrimming08#0/calosubjetsTrimming08#0.index',
#  'calosubjetsTrimming08#0/calosubjetsTrimming08#0.collectionID',
#  'calosubjetsPruning08',
#  'calosubjetsPruning08/calosubjetsPruning08.core.area',
#  'calosubjetsPruning08/calosubjetsPruning08.core.bits',
#  'calosubjetsPruning08/calosubjetsPruning08.core.p4.mass',
#  'calosubjetsPruning08/calosubjetsPruning08.core.p4.px',
#  'calosubjetsPruning08/calosubjetsPruning08.core.p4.py',
#  'calosubjetsPruning08/calosubjetsPruning08.core.p4.pz',
#  'calosubjetsPruning08/calosubjetsPruning08.particles_begin',
#  'calosubjetsPruning08/calosubjetsPruning08.particles_end',
#  'calosubjetsPruning08#0',
#  'calosubjetsPruning08#0/calosubjetsPruning08#0.index',
#  'calosubjetsPruning08#0/calosubjetsPruning08#0.collectionID',
#  'calosubjetsSoftDrop08',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.core.area',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.core.bits',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.core.p4.mass',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.core.p4.px',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.core.p4.py',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.core.p4.pz',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.particles_begin',
#  'calosubjetsSoftDrop08/calosubjetsSoftDrop08.particles_end',
#  'calosubjetsSoftDrop08#0',
#  'calosubjetsSoftDrop08#0/calosubjetsSoftDrop08#0.index',
#  'calosubjetsSoftDrop08#0/calosubjetsSoftDrop08#0.collectionID',
#  'calojets15',
#  'calojets15/calojets15.core.area',
#  'calojets15/calojets15.core.bits',
#  'calojets15/calojets15.core.p4.mass',
#  'calojets15/calojets15.core.p4.px',
#  'calojets15/calojets15.core.p4.py',
#  'calojets15/calojets15.core.p4.pz',
#  'calojets15/calojets15.particles_begin',
#  'calojets15/calojets15.particles_end',
#  'calojets15#0',
#  'calojets15#0/calojets15#0.index',
#  'calojets15#0/calojets15#0.collectionID',
#  'calojetsFlavor15',
#  'calojetsFlavor15/calojetsFlavor15.tag',
#  'calojetsFlavor15#0',
#  'calojetsFlavor15#0/calojetsFlavor15#0.index',
#  'calojetsFlavor15#0/calojetsFlavor15#0.collectionID',
#  'calobTags15',
#  'calobTags15/calobTags15.tag',
#  'calobTags15#0',
#  'calobTags15#0/calobTags15#0.index',
#  'calobTags15#0/calobTags15#0.collectionID',
#  'calocTags15',
#  'calocTags15/calocTags15.tag',
#  'calocTags15#0',
#  'calocTags15#0/calocTags15#0.index',
#  'calocTags15#0/calocTags15#0.collectionID',
#  'calotauTags15',
#  'calotauTags15/calotauTags15.tag',
#  'calotauTags15#0',
#  'calotauTags15#0/calotauTags15#0.index',
#  'calotauTags15#0/calotauTags15#0.collectionID',
#  'calojetParts15',
#  'calojetParts15/calojetParts15.core.bits',
#  'calojetParts15/calojetParts15.core.charge',
#  'calojetParts15/calojetParts15.core.p4.mass',
#  'calojetParts15/calojetParts15.core.p4.px',
#  'calojetParts15/calojetParts15.core.p4.py',
#  'calojetParts15/calojetParts15.core.p4.pz',
#  'calojetParts15/calojetParts15.core.pdgId',
#  'calojetParts15/calojetParts15.core.status',
#  'calojetParts15/calojetParts15.core.vertex.x',
#  'calojetParts15/calojetParts15.core.vertex.y',
#  'calojetParts15/calojetParts15.core.vertex.z',
#  'calojetParts15/calojetParts15.tracks_begin',
#  'calojetParts15/calojetParts15.tracks_end',
#  'calojetParts15/calojetParts15.clusters_begin',
#  'calojetParts15/calojetParts15.clusters_end',
#  'calojetParts15#0',
#  'calojetParts15#0/calojetParts15#0.index',
#  'calojetParts15#0/calojetParts15#0.collectionID',
#  'calojetParts15#1',
#  'calojetParts15#1/calojetParts15#1.index',
#  'calojetParts15#1/calojetParts15#1.collectionID',
#  'calojetsOneSubJettiness15',
#  'calojetsOneSubJettiness15/calojetsOneSubJettiness15.tag',
#  'calojetsOneSubJettiness15#0',
#  'calojetsOneSubJettiness15#0/calojetsOneSubJettiness15#0.index',
#  'calojetsOneSubJettiness15#0/calojetsOneSubJettiness15#0.collectionID',
#  'calojetsTwoSubJettiness15',
#  'calojetsTwoSubJettiness15/calojetsTwoSubJettiness15.tag',
#  'calojetsTwoSubJettiness15#0',
#  'calojetsTwoSubJettiness15#0/calojetsTwoSubJettiness15#0.index',
#  'calojetsTwoSubJettiness15#0/calojetsTwoSubJettiness15#0.collectionID',
#  'calojetsThreeSubJettiness15',
#  'calojetsThreeSubJettiness15/calojetsThreeSubJettiness15.tag',
#  'calojetsThreeSubJettiness15#0',
#  'calojetsThreeSubJettiness15#0/calojetsThreeSubJettiness15#0.index',
#  'calojetsThreeSubJettiness15#0/calojetsThreeSubJettiness15#0.collectionID',
#  'calosubjetsTrimmingTagged15',
#  'calosubjetsTrimmingTagged15/calosubjetsTrimmingTagged15.subjets_begin',
#  'calosubjetsTrimmingTagged15/calosubjetsTrimmingTagged15.subjets_end',
#  'calosubjetsTrimmingTagged15#0',
#  'calosubjetsTrimmingTagged15#0/calosubjetsTrimmingTagged15#0.index',
#  'calosubjetsTrimmingTagged15#0/calosubjetsTrimmingTagged15#0.collectionID',
#  'calosubjetsTrimmingTagged15#1',
#  'calosubjetsTrimmingTagged15#1/calosubjetsTrimmingTagged15#1.index',
#  'calosubjetsTrimmingTagged15#1/calosubjetsTrimmingTagged15#1.collectionID',
#  'calosubjetsPruningTagged15',
#  'calosubjetsPruningTagged15/calosubjetsPruningTagged15.subjets_begin',
#  'calosubjetsPruningTagged15/calosubjetsPruningTagged15.subjets_end',
#  'calosubjetsPruningTagged15#0',
#  'calosubjetsPruningTagged15#0/calosubjetsPruningTagged15#0.index',
#  'calosubjetsPruningTagged15#0/calosubjetsPruningTagged15#0.collectionID',
#  'calosubjetsPruningTagged15#1',
#  'calosubjetsPruningTagged15#1/calosubjetsPruningTagged15#1.index',
#  'calosubjetsPruningTagged15#1/calosubjetsPruningTagged15#1.collectionID',
#  'calosubjetsSoftDropTagged15',
#  'calosubjetsSoftDropTagged15/calosubjetsSoftDropTagged15.subjets_begin',
#  'calosubjetsSoftDropTagged15/calosubjetsSoftDropTagged15.subjets_end',
#  'calosubjetsSoftDropTagged15#0',
#  'calosubjetsSoftDropTagged15#0/calosubjetsSoftDropTagged15#0.index',
#  'calosubjetsSoftDropTagged15#0/calosubjetsSoftDropTagged15#0.collectionID',
#  'calosubjetsSoftDropTagged15#1',
#  'calosubjetsSoftDropTagged15#1/calosubjetsSoftDropTagged15#1.index',
#  'calosubjetsSoftDropTagged15#1/calosubjetsSoftDropTagged15#1.collectionID',
#  'calosubjetsTrimming15',
#  'calosubjetsTrimming15/calosubjetsTrimming15.core.area',
#  'calosubjetsTrimming15/calosubjetsTrimming15.core.bits',
#  'calosubjetsTrimming15/calosubjetsTrimming15.core.p4.mass',
#  'calosubjetsTrimming15/calosubjetsTrimming15.core.p4.px',
#  'calosubjetsTrimming15/calosubjetsTrimming15.core.p4.py',
#  'calosubjetsTrimming15/calosubjetsTrimming15.core.p4.pz',
#  'calosubjetsTrimming15/calosubjetsTrimming15.particles_begin',
#  'calosubjetsTrimming15/calosubjetsTrimming15.particles_end',
#  'calosubjetsTrimming15#0',
#  'calosubjetsTrimming15#0/calosubjetsTrimming15#0.index',
#  'calosubjetsTrimming15#0/calosubjetsTrimming15#0.collectionID',
#  'calosubjetsPruning15',
#  'calosubjetsPruning15/calosubjetsPruning15.core.area',
#  'calosubjetsPruning15/calosubjetsPruning15.core.bits',
#  'calosubjetsPruning15/calosubjetsPruning15.core.p4.mass',
#  'calosubjetsPruning15/calosubjetsPruning15.core.p4.px',
#  'calosubjetsPruning15/calosubjetsPruning15.core.p4.py',
#  'calosubjetsPruning15/calosubjetsPruning15.core.p4.pz',
#  'calosubjetsPruning15/calosubjetsPruning15.particles_begin',
#  'calosubjetsPruning15/calosubjetsPruning15.particles_end',
#  'calosubjetsPruning15#0',
#  'calosubjetsPruning15#0/calosubjetsPruning15#0.index',
#  'calosubjetsPruning15#0/calosubjetsPruning15#0.collectionID',
#  'calosubjetsSoftDrop15',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.core.area',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.core.bits',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.core.p4.mass',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.core.p4.px',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.core.p4.py',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.core.p4.pz',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.particles_begin',
#  'calosubjetsSoftDrop15/calosubjetsSoftDrop15.particles_end',
#  'calosubjetsSoftDrop15#0',
#  'calosubjetsSoftDrop15#0/calosubjetsSoftDrop15#0.index',
#  'calosubjetsSoftDrop15#0/calosubjetsSoftDrop15#0.collectionID',
#  'pfjets02',
#  'pfjets02/pfjets02.core.area',
#  'pfjets02/pfjets02.core.bits',
#  'pfjets02/pfjets02.core.p4.mass',
#  'pfjets02/pfjets02.core.p4.px',
#  'pfjets02/pfjets02.core.p4.py',
#  'pfjets02/pfjets02.core.p4.pz',
#  'pfjets02/pfjets02.particles_begin',
#  'pfjets02/pfjets02.particles_end',
#  'pfjets02#0',
#  'pfjets02#0/pfjets02#0.index',
#  'pfjets02#0/pfjets02#0.collectionID',
#  'pfjetsFlavor02',
#  'pfjetsFlavor02/pfjetsFlavor02.tag',
#  'pfjetsFlavor02#0',
#  'pfjetsFlavor02#0/pfjetsFlavor02#0.index',
#  'pfjetsFlavor02#0/pfjetsFlavor02#0.collectionID',
#  'pfbTags02',
#  'pfbTags02/pfbTags02.tag',
#  'pfbTags02#0',
#  'pfbTags02#0/pfbTags02#0.index',
#  'pfbTags02#0/pfbTags02#0.collectionID',
#  'pfcTags02',
#  'pfcTags02/pfcTags02.tag',
#  'pfcTags02#0',
#  'pfcTags02#0/pfcTags02#0.index',
#  'pfcTags02#0/pfcTags02#0.collectionID',
#  'pftauTags02',
#  'pftauTags02/pftauTags02.tag',
#  'pftauTags02#0',
#  'pftauTags02#0/pftauTags02#0.index',
#  'pftauTags02#0/pftauTags02#0.collectionID',
#  'pfjetParts02',
#  'pfjetParts02/pfjetParts02.core.bits',
#  'pfjetParts02/pfjetParts02.core.charge',
#  'pfjetParts02/pfjetParts02.core.p4.mass',
#  'pfjetParts02/pfjetParts02.core.p4.px',
#  'pfjetParts02/pfjetParts02.core.p4.py',
#  'pfjetParts02/pfjetParts02.core.p4.pz',
#  'pfjetParts02/pfjetParts02.core.pdgId',
#  'pfjetParts02/pfjetParts02.core.status',
#  'pfjetParts02/pfjetParts02.core.vertex.x',
#  'pfjetParts02/pfjetParts02.core.vertex.y',
#  'pfjetParts02/pfjetParts02.core.vertex.z',
#  'pfjetParts02/pfjetParts02.tracks_begin',
#  'pfjetParts02/pfjetParts02.tracks_end',
#  'pfjetParts02/pfjetParts02.clusters_begin',
#  'pfjetParts02/pfjetParts02.clusters_end',
#  'pfjetParts02#0',
#  'pfjetParts02#0/pfjetParts02#0.index',
#  'pfjetParts02#0/pfjetParts02#0.collectionID',
#  'pfjetParts02#1',
#  'pfjetParts02#1/pfjetParts02#1.index',
#  'pfjetParts02#1/pfjetParts02#1.collectionID',
#  'pfjetsOneSubJettiness02',
#  'pfjetsOneSubJettiness02/pfjetsOneSubJettiness02.tag',
#  'pfjetsOneSubJettiness02#0',
#  'pfjetsOneSubJettiness02#0/pfjetsOneSubJettiness02#0.index',
#  'pfjetsOneSubJettiness02#0/pfjetsOneSubJettiness02#0.collectionID',
#  'pfjetsTwoSubJettiness02',
#  'pfjetsTwoSubJettiness02/pfjetsTwoSubJettiness02.tag',
#  'pfjetsTwoSubJettiness02#0',
#  'pfjetsTwoSubJettiness02#0/pfjetsTwoSubJettiness02#0.index',
#  'pfjetsTwoSubJettiness02#0/pfjetsTwoSubJettiness02#0.collectionID',
#  'pfjetsThreeSubJettiness02',
#  'pfjetsThreeSubJettiness02/pfjetsThreeSubJettiness02.tag',
#  'pfjetsThreeSubJettiness02#0',
#  'pfjetsThreeSubJettiness02#0/pfjetsThreeSubJettiness02#0.index',
#  'pfjetsThreeSubJettiness02#0/pfjetsThreeSubJettiness02#0.collectionID',
#  'pfsubjetsTrimmingTagged02',
#  'pfsubjetsTrimmingTagged02/pfsubjetsTrimmingTagged02.subjets_begin',
#  'pfsubjetsTrimmingTagged02/pfsubjetsTrimmingTagged02.subjets_end',
#  'pfsubjetsTrimmingTagged02#0',
#  'pfsubjetsTrimmingTagged02#0/pfsubjetsTrimmingTagged02#0.index',
#  'pfsubjetsTrimmingTagged02#0/pfsubjetsTrimmingTagged02#0.collectionID',
#  'pfsubjetsTrimmingTagged02#1',
#  'pfsubjetsTrimmingTagged02#1/pfsubjetsTrimmingTagged02#1.index',
#  'pfsubjetsTrimmingTagged02#1/pfsubjetsTrimmingTagged02#1.collectionID',
#  'pfsubjetsPruningTagged02',
#  'pfsubjetsPruningTagged02/pfsubjetsPruningTagged02.subjets_begin',
#  'pfsubjetsPruningTagged02/pfsubjetsPruningTagged02.subjets_end',
#  'pfsubjetsPruningTagged02#0',
#  'pfsubjetsPruningTagged02#0/pfsubjetsPruningTagged02#0.index',
#  'pfsubjetsPruningTagged02#0/pfsubjetsPruningTagged02#0.collectionID',
#  'pfsubjetsPruningTagged02#1',
#  'pfsubjetsPruningTagged02#1/pfsubjetsPruningTagged02#1.index',
#  'pfsubjetsPruningTagged02#1/pfsubjetsPruningTagged02#1.collectionID',
#  'pfsubjetsSoftDropTagged02',
#  'pfsubjetsSoftDropTagged02/pfsubjetsSoftDropTagged02.subjets_begin',
#  'pfsubjetsSoftDropTagged02/pfsubjetsSoftDropTagged02.subjets_end',
#  'pfsubjetsSoftDropTagged02#0',
#  'pfsubjetsSoftDropTagged02#0/pfsubjetsSoftDropTagged02#0.index',
#  'pfsubjetsSoftDropTagged02#0/pfsubjetsSoftDropTagged02#0.collectionID',
#  'pfsubjetsSoftDropTagged02#1',
#  'pfsubjetsSoftDropTagged02#1/pfsubjetsSoftDropTagged02#1.index',
#  'pfsubjetsSoftDropTagged02#1/pfsubjetsSoftDropTagged02#1.collectionID',
#  'pfsubjetsTrimming02',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.core.area',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.core.bits',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.core.p4.mass',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.core.p4.px',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.core.p4.py',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.core.p4.pz',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.particles_begin',
#  'pfsubjetsTrimming02/pfsubjetsTrimming02.particles_end',
#  'pfsubjetsTrimming02#0',
#  'pfsubjetsTrimming02#0/pfsubjetsTrimming02#0.index',
#  'pfsubjetsTrimming02#0/pfsubjetsTrimming02#0.collectionID',
#  'pfsubjetsPruning02',
#  'pfsubjetsPruning02/pfsubjetsPruning02.core.area',
#  'pfsubjetsPruning02/pfsubjetsPruning02.core.bits',
#  'pfsubjetsPruning02/pfsubjetsPruning02.core.p4.mass',
#  'pfsubjetsPruning02/pfsubjetsPruning02.core.p4.px',
#  'pfsubjetsPruning02/pfsubjetsPruning02.core.p4.py',
#  'pfsubjetsPruning02/pfsubjetsPruning02.core.p4.pz',
#  'pfsubjetsPruning02/pfsubjetsPruning02.particles_begin',
#  'pfsubjetsPruning02/pfsubjetsPruning02.particles_end',
#  'pfsubjetsPruning02#0',
#  'pfsubjetsPruning02#0/pfsubjetsPruning02#0.index',
#  'pfsubjetsPruning02#0/pfsubjetsPruning02#0.collectionID',
#  'pfsubjetsSoftDrop02',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.core.area',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.core.bits',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.core.p4.mass',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.core.p4.px',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.core.p4.py',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.core.p4.pz',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.particles_begin',
#  'pfsubjetsSoftDrop02/pfsubjetsSoftDrop02.particles_end',
#  'pfsubjetsSoftDrop02#0',
#  'pfsubjetsSoftDrop02#0/pfsubjetsSoftDrop02#0.index',
#  'pfsubjetsSoftDrop02#0/pfsubjetsSoftDrop02#0.collectionID',
#  'pfjets04',
#  'pfjets04/pfjets04.core.area',
#  'pfjets04/pfjets04.core.bits',
#  'pfjets04/pfjets04.core.p4.mass',
#  'pfjets04/pfjets04.core.p4.px',
#  'pfjets04/pfjets04.core.p4.py',
#  'pfjets04/pfjets04.core.p4.pz',
#  'pfjets04/pfjets04.particles_begin',
#  'pfjets04/pfjets04.particles_end',
#  'pfjets04#0',
#  'pfjets04#0/pfjets04#0.index',
#  'pfjets04#0/pfjets04#0.collectionID',
#  'pfjetsFlavor04',
#  'pfjetsFlavor04/pfjetsFlavor04.tag',
#  'pfjetsFlavor04#0',
#  'pfjetsFlavor04#0/pfjetsFlavor04#0.index',
#  'pfjetsFlavor04#0/pfjetsFlavor04#0.collectionID',
#  'pfbTags04',
#  'pfbTags04/pfbTags04.tag',
#  'pfbTags04#0',
#  'pfbTags04#0/pfbTags04#0.index',
#  'pfbTags04#0/pfbTags04#0.collectionID',
#  'pfcTags04',
#  'pfcTags04/pfcTags04.tag',
#  'pfcTags04#0',
#  'pfcTags04#0/pfcTags04#0.index',
#  'pfcTags04#0/pfcTags04#0.collectionID',
#  'pftauTags04',
#  'pftauTags04/pftauTags04.tag',
#  'pftauTags04#0',
#  'pftauTags04#0/pftauTags04#0.index',
#  'pftauTags04#0/pftauTags04#0.collectionID',
#  'pfjetParts04',
#  'pfjetParts04/pfjetParts04.core.bits',
#  'pfjetParts04/pfjetParts04.core.charge',
#  'pfjetParts04/pfjetParts04.core.p4.mass',
#  'pfjetParts04/pfjetParts04.core.p4.px',
#  'pfjetParts04/pfjetParts04.core.p4.py',
#  'pfjetParts04/pfjetParts04.core.p4.pz',
#  'pfjetParts04/pfjetParts04.core.pdgId',
#  'pfjetParts04/pfjetParts04.core.status',
#  'pfjetParts04/pfjetParts04.core.vertex.x',
#  'pfjetParts04/pfjetParts04.core.vertex.y',
#  'pfjetParts04/pfjetParts04.core.vertex.z',
#  'pfjetParts04/pfjetParts04.tracks_begin',
#  'pfjetParts04/pfjetParts04.tracks_end',
#  'pfjetParts04/pfjetParts04.clusters_begin',
#  'pfjetParts04/pfjetParts04.clusters_end',
#  'pfjetParts04#0',
#  'pfjetParts04#0/pfjetParts04#0.index',
#  'pfjetParts04#0/pfjetParts04#0.collectionID',
#  'pfjetParts04#1',
#  'pfjetParts04#1/pfjetParts04#1.index',
#  'pfjetParts04#1/pfjetParts04#1.collectionID',
#  'pfjetsOneSubJettiness04',
#  'pfjetsOneSubJettiness04/pfjetsOneSubJettiness04.tag',
#  'pfjetsOneSubJettiness04#0',
#  'pfjetsOneSubJettiness04#0/pfjetsOneSubJettiness04#0.index',
#  'pfjetsOneSubJettiness04#0/pfjetsOneSubJettiness04#0.collectionID',
#  'pfjetsTwoSubJettiness04',
#  'pfjetsTwoSubJettiness04/pfjetsTwoSubJettiness04.tag',
#  ...]

# %%
events["electrons"].array()
# Out:
# <Array [{'electrons.core.bits': ..., ...}, ...] type='4332 * {"electrons.co...'>

# %%
e_momentum = events.arrays(["electrons.core.p4.px","electrons.core.p4.py","electrons.core.p4.pz"], library="pd")
e_momentum
# Out:
#                                    electrons.core.p4.px  \
# 0              [-23.97795867919922, 4.0764641761779785]
# 1                                  [-0.883417010307312]
# 2            [-8.564638137817383, -0.29399582743644714]
# 3            [-0.06099341809749603, 2.1221694946289062]
# 4     [1.7704945802688599, 0.7803094387054443, 1.026...
# ...                                                 ...
# 4327           [-5.459677219390869, -50.39870834350586]
# 4328                              [-14.424826622009277]
# 4329                                                 []
# 4330  [-0.9636491537094116, -1.520751714706421, 0.30...
# 4331           [0.3074081540107727, 0.9786341190338135]
#
#                                    electrons.core.p4.py  \
# 0              [-1.2891672849655151, 1.005417823791504]
# 1                                  [-6.596574306488037]
# 2               [43.39677810668945, 0.9294815063476562]
# 3                 [6.355966091156006, 8.95730209350586]
# 4     [2.3572487831115723, 1.2632160186767578, 1.666...
# ...                                                 ...
# 4327         [-7.5544867515563965, -10.971610069274902]
# 4328                              [-6.5418524742126465]
# 4329                                                 []
# 4330  [0.8544232845306396, 1.4013516902923584, 0.853...
# 4331          [-2.0726726055145264, 0.6636313199996948]
#
#                                    electrons.core.p4.pz
# 0              [-15.616803169250488, 5.760061264038086]
# 1                                  [-8.828859329223633]
# 2               [-68.02328491210938, 3.178347110748291]
# 3              [-0.6071939468383789, 37.46609115600586]
# 4     [-163.9446563720703, -3.3978943824768066, -4.4...
# ...                                                 ...
# 4327            [-44.609657287597656, 91.4759292602539]
# 4328                                [53.04682922363281]
# 4329                                                 []
# 4330  [-20.09828758239746, -18.07868003845215, -0.24...
# 4331           [0.47499915957450867, 61.86579895019531]
#
# [4332 rows x 3 columns]

# %%
mu_momentum = events.arrays(["muons.core.p4.px","muons.core.p4.py","muons.core.p4.pz"], library="pd")
mu_momentum
# Out:
#                                        muons.core.p4.px  \
# 0                                                    []
# 1     [-169.58860778808594, -0.7977475523948669, -1....
# 2                                [-0.49343809485435486]
# 3                                  [1.0810385942459106]
# 4                                                    []
# ...                                                 ...
# 4327                                                 []
# 4328          [-2.9458043575286865, 28.740907669067383]
# 4329                                [65.10124206542969]
# 4330  [-23.823650360107422, 0.19225989282131195, 0.5...
# 4331           [-0.4289323687553406, 5.405364990234375]
#
#                                        muons.core.p4.py  \
# 0                                                    []
# 1     [132.80262756347656, 40.59326934814453, 2.9712...
# 2                                   [3.045670509338379]
# 3                                [-0.40362676978111267]
# 4                                                    []
# ...                                                 ...
# 4327                                                 []
# 4328              [-4.010786056518555, 26.262451171875]
# 4329                                [31.02659797668457]
# 4330  [0.5109038949012756, -0.7831055521965027, 0.75...
# 4331           [-0.558642566204071, 2.5216095447540283]
#
#                                        muons.core.p4.pz
# 0                                                    []
# 1     [91.7788314819336, -3.875622272491455, 0.00219...
# 2                                  [-16.77739715576172]
# 3                                   [17.83453941345215]
# 4                                                    []
# ...                                                 ...
# 4327                                                 []
# 4328            [23.488388061523438, 331.7608642578125]
# 4329                                [-163.862548828125]
# 4330  [166.89398193359375, -1.2991125583648682, -0.4...
# 4331           [-107.9757308959961, 0.4050377905368805]
#
# [4332 rows x 3 columns]
