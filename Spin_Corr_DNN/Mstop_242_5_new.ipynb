# %%
import ROOT
import uproot
import numpy as np
import pandas as pd
import torch 
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.22/00

# %%
sig_df = pd.read_pickle('DNN_ips/SUSY_Mstop_242_5_mchi_60.pkl')
tt_df  = pd.read_pickle('DNN_ips/ttbar.pkl')
vv_df  = pd.read_pickle('DNN_ips/VV.pkl')
st_df  = pd.read_pickle('DNN_ips/Single_top.pkl')
sat_df = pd.read_pickle('DNN_ips/Single_antitop.pkl')

# %%
Pol_rw  = np.loadtxt('txt_files/SUSY_weights_mstop_175_mchi_7_5_Pol_minus1.txt')
Ecom_rw = np.loadtxt('txt_files/SUSY_Ecom_rw.txt')
Rw      = Pol_rw * Ecom_rw

# %%
# Standardize
sig_mean = sig_df.mean()
sig_std  = sig_df.std()

tt_mean = tt_df.mean()
tt_std  = tt_df.std()

st_mean = st_df.mean()
st_std  = st_df.std()

vv_mean = vv_df.mean()
vv_std  = vv_df.std()

sat_mean = sat_df.mean()
sat_std  = sat_df.std()

sig_df = (sig_df - sig_mean)/ sig_std
tt_df  = (tt_df  - tt_mean)/ tt_std
st_df  = (st_df  - st_mean)/ st_std
vv_df  = (vv_df  - vv_mean)/ vv_std
sat_df = (sat_df  - sat_mean)/ sat_std

# %%
# Set both to equal sizes 
# Reducing the bkg dataframe size

sig_df_train = sig_df[1:15000]
tt_df_train  = tt_df[1:30000]
st_df_train  = st_df[1:5000]
sat_df_train = sat_df[1:5000]
vv_df_train  = vv_df[1:2000]

# %%
bkgList = [tt_df_train, st_df_train, sat_df_train, vv_df_train]  # List of your dataframes

bkg_df_train = pd.concat(bkgList)

signal = sig_df_train.values
bkg    = bkg_df_train.values

sig_label = np.ones(len(signal))
bkg_label = np.zeros(len(bkg))

data      = np.concatenate((signal,bkg))
label     = np.concatenate((sig_label,bkg_label))

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=2, shuffle=True)
skf.get_n_splits(data, label)
skf.split(data, label)
# Out:
# <generator object _BaseKFold.split at 0x7fa130826120>

# %%
for train_index, test_index in skf.split(data, label):
    print("TRAIN:", train_index, "TEST:", test_index)
    x_train, x_test = data[train_index], data[test_index]
    y_train, y_test = label[train_index], label[test_index]
# Out:
# TRAIN: [    1     2     3 ... 56991 56992 56994] TEST: [    0     4     7 ... 56988 56989 56993]
# TRAIN: [    0     4     7 ... 56988 56989 56993] TEST: [    1     2     3 ... 56991 56992 56994]

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout
from skopt import gp_minimize

model = Sequential()
model.add(Dense(100, input_dim = 19  ,activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(100, input_dim = 100 ,activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2000
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 12,201
# Trainable params: 12,201
# Non-trainable params: 0
# _________________________________________________________________
# 2021-02-26 01:35:33.688254: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-02-26 01:35:33.719276: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa13553ca40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-26 01:35:33.719304: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
hist = model.fit(x_train, y_train, batch_size=100, epochs=1000,verbose=1, shuffle=True, validation_split=0.2,
                  callbacks=[EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='min'),
                  ModelCheckpoint(filepath='model.h5', verbose=0)])
# Out:
# Epoch 1/1000
# 228/228 [==============================] - 1s 5ms/step - loss: 0.6037 - accuracy: 0.7136 - val_loss: 0.5769 - val_accuracy: 0.7402
# Epoch 2/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5862 - accuracy: 0.7352 - val_loss: 0.5736 - val_accuracy: 0.7402
# Epoch 3/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5856 - accuracy: 0.7355 - val_loss: 0.5725 - val_accuracy: 0.7402
# Epoch 4/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5816 - accuracy: 0.7359 - val_loss: 0.5719 - val_accuracy: 0.7402
# Epoch 5/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5796 - accuracy: 0.7359 - val_loss: 0.5734 - val_accuracy: 0.7402
# Epoch 6/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5792 - accuracy: 0.7360 - val_loss: 0.5731 - val_accuracy: 0.7402
# Epoch 7/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5783 - accuracy: 0.7358 - val_loss: 0.5719 - val_accuracy: 0.7402
# Epoch 8/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5761 - accuracy: 0.7360 - val_loss: 0.5706 - val_accuracy: 0.7402
# Epoch 9/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5748 - accuracy: 0.7360 - val_loss: 0.5683 - val_accuracy: 0.7402
# Epoch 10/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5727 - accuracy: 0.7361 - val_loss: 0.5673 - val_accuracy: 0.7402
# Epoch 11/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5695 - accuracy: 0.7361 - val_loss: 0.5610 - val_accuracy: 0.7402
# Epoch 12/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5631 - accuracy: 0.7371 - val_loss: 0.5520 - val_accuracy: 0.7404
# Epoch 13/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5495 - accuracy: 0.7439 - val_loss: 0.5254 - val_accuracy: 0.7509
# Epoch 14/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5148 - accuracy: 0.7667 - val_loss: 0.4625 - val_accuracy: 0.7930
# Epoch 15/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.4487 - accuracy: 0.8078 - val_loss: 0.3708 - val_accuracy: 0.8521
# Epoch 16/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3764 - accuracy: 0.8436 - val_loss: 0.3098 - val_accuracy: 0.8744
# Epoch 17/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.3351 - accuracy: 0.8597 - val_loss: 0.2808 - val_accuracy: 0.8849
# Epoch 18/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.3169 - accuracy: 0.8656 - val_loss: 0.2676 - val_accuracy: 0.8888
# Epoch 19/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.3063 - accuracy: 0.8721 - val_loss: 0.2619 - val_accuracy: 0.8940
# Epoch 20/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2963 - accuracy: 0.8734 - val_loss: 0.2516 - val_accuracy: 0.8979
# Epoch 21/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2947 - accuracy: 0.8755 - val_loss: 0.2477 - val_accuracy: 0.8967
# Epoch 22/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2855 - accuracy: 0.8797 - val_loss: 0.2445 - val_accuracy: 0.9009
# Epoch 23/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2829 - accuracy: 0.8813 - val_loss: 0.2396 - val_accuracy: 0.8993
# Epoch 24/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2803 - accuracy: 0.8818 - val_loss: 0.2403 - val_accuracy: 0.9025
# Epoch 25/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2776 - accuracy: 0.8828 - val_loss: 0.2356 - val_accuracy: 0.9032
# Epoch 26/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2760 - accuracy: 0.8821 - val_loss: 0.2433 - val_accuracy: 0.9007
# Epoch 27/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2713 - accuracy: 0.8858 - val_loss: 0.2343 - val_accuracy: 0.9044
# Epoch 28/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2707 - accuracy: 0.8863 - val_loss: 0.2343 - val_accuracy: 0.9040
# Epoch 29/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2702 - accuracy: 0.8854 - val_loss: 0.2368 - val_accuracy: 0.8998
# Epoch 30/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2708 - accuracy: 0.8852 - val_loss: 0.2333 - val_accuracy: 0.9042
# Epoch 31/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2657 - accuracy: 0.8878 - val_loss: 0.2307 - val_accuracy: 0.9047
# Epoch 32/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2671 - accuracy: 0.8867 - val_loss: 0.2332 - val_accuracy: 0.9067
# Epoch 33/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2650 - accuracy: 0.8882 - val_loss: 0.2321 - val_accuracy: 0.9037
# Epoch 34/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2621 - accuracy: 0.8898 - val_loss: 0.2276 - val_accuracy: 0.9091
# Epoch 35/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2591 - accuracy: 0.8900 - val_loss: 0.2250 - val_accuracy: 0.9084
# Epoch 36/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2608 - accuracy: 0.8907 - val_loss: 0.2267 - val_accuracy: 0.9075
# Epoch 37/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2590 - accuracy: 0.8904 - val_loss: 0.2262 - val_accuracy: 0.9070
# Epoch 38/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2582 - accuracy: 0.8901 - val_loss: 0.2330 - val_accuracy: 0.9016
# Epoch 39/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2606 - accuracy: 0.8897 - val_loss: 0.2248 - val_accuracy: 0.9075
# Epoch 40/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2564 - accuracy: 0.8922 - val_loss: 0.2294 - val_accuracy: 0.9014
# Epoch 41/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2575 - accuracy: 0.8892 - val_loss: 0.2255 - val_accuracy: 0.9075
# Epoch 42/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2584 - accuracy: 0.8893 - val_loss: 0.2276 - val_accuracy: 0.9061
# Epoch 43/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2533 - accuracy: 0.8924 - val_loss: 0.2245 - val_accuracy: 0.9075
# Epoch 44/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2542 - accuracy: 0.8906 - val_loss: 0.2228 - val_accuracy: 0.9084
# Epoch 45/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2530 - accuracy: 0.8926 - val_loss: 0.2280 - val_accuracy: 0.9042
# Epoch 46/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2534 - accuracy: 0.8924 - val_loss: 0.2234 - val_accuracy: 0.9053
# Epoch 47/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2532 - accuracy: 0.8923 - val_loss: 0.2213 - val_accuracy: 0.9072
# Epoch 48/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2508 - accuracy: 0.8924 - val_loss: 0.2205 - val_accuracy: 0.9086
# Epoch 49/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2506 - accuracy: 0.8946 - val_loss: 0.2211 - val_accuracy: 0.9081
# Epoch 50/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2535 - accuracy: 0.8923 - val_loss: 0.2283 - val_accuracy: 0.9044
# Epoch 51/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2513 - accuracy: 0.8945 - val_loss: 0.2212 - val_accuracy: 0.9091
# Epoch 52/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2495 - accuracy: 0.8923 - val_loss: 0.2243 - val_accuracy: 0.9074
# Epoch 53/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2533 - accuracy: 0.8912 - val_loss: 0.2211 - val_accuracy: 0.9093
# Epoch 54/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2482 - accuracy: 0.8946 - val_loss: 0.2185 - val_accuracy: 0.9082
# Epoch 55/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2486 - accuracy: 0.8953 - val_loss: 0.2273 - val_accuracy: 0.9051
# Epoch 56/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2512 - accuracy: 0.8932 - val_loss: 0.2216 - val_accuracy: 0.9072
# Epoch 57/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2470 - accuracy: 0.8970 - val_loss: 0.2176 - val_accuracy: 0.9102
# Epoch 58/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2456 - accuracy: 0.8948 - val_loss: 0.2218 - val_accuracy: 0.9067
# Epoch 59/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2475 - accuracy: 0.8945 - val_loss: 0.2191 - val_accuracy: 0.9100
# Epoch 60/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2476 - accuracy: 0.8955 - val_loss: 0.2196 - val_accuracy: 0.9079
# Epoch 61/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2450 - accuracy: 0.8956 - val_loss: 0.2212 - val_accuracy: 0.9053
# Epoch 62/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2479 - accuracy: 0.8955 - val_loss: 0.2182 - val_accuracy: 0.9109
# Epoch 63/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2468 - accuracy: 0.8952 - val_loss: 0.2216 - val_accuracy: 0.9079
# Epoch 64/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2457 - accuracy: 0.8949 - val_loss: 0.2198 - val_accuracy: 0.9072
# Epoch 65/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2457 - accuracy: 0.8942 - val_loss: 0.2200 - val_accuracy: 0.9061
# Epoch 66/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2492 - accuracy: 0.8945 - val_loss: 0.2239 - val_accuracy: 0.9058
# Epoch 67/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2457 - accuracy: 0.8947 - val_loss: 0.2174 - val_accuracy: 0.9116
# Epoch 68/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2468 - accuracy: 0.8950 - val_loss: 0.2187 - val_accuracy: 0.9111
# Epoch 69/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2434 - accuracy: 0.8975 - val_loss: 0.2173 - val_accuracy: 0.9098
# Epoch 70/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2424 - accuracy: 0.8971 - val_loss: 0.2172 - val_accuracy: 0.9089
# Epoch 71/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2447 - accuracy: 0.8948 - val_loss: 0.2165 - val_accuracy: 0.9102
# Epoch 72/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2437 - accuracy: 0.8962 - val_loss: 0.2171 - val_accuracy: 0.9107
# Epoch 73/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2455 - accuracy: 0.8964 - val_loss: 0.2142 - val_accuracy: 0.9089
# Epoch 74/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2448 - accuracy: 0.8951 - val_loss: 0.2184 - val_accuracy: 0.9102
# Epoch 75/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2419 - accuracy: 0.8967 - val_loss: 0.2186 - val_accuracy: 0.9126
# Epoch 76/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2421 - accuracy: 0.8993 - val_loss: 0.2172 - val_accuracy: 0.9095
# Epoch 77/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2443 - accuracy: 0.8954 - val_loss: 0.2203 - val_accuracy: 0.9070
# Epoch 78/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2434 - accuracy: 0.8957 - val_loss: 0.2152 - val_accuracy: 0.9102
# Epoch 79/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2395 - accuracy: 0.8977 - val_loss: 0.2199 - val_accuracy: 0.9072
# Epoch 80/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2433 - accuracy: 0.8972 - val_loss: 0.2196 - val_accuracy: 0.9088
# Epoch 81/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2398 - accuracy: 0.8989 - val_loss: 0.2169 - val_accuracy: 0.9091
# Epoch 82/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2408 - accuracy: 0.8979 - val_loss: 0.2196 - val_accuracy: 0.9065
# Epoch 83/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2415 - accuracy: 0.8976 - val_loss: 0.2161 - val_accuracy: 0.9112
# Epoch 84/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2410 - accuracy: 0.8978 - val_loss: 0.2184 - val_accuracy: 0.9089
# Epoch 85/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2416 - accuracy: 0.8962 - val_loss: 0.2165 - val_accuracy: 0.9114
# Epoch 86/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2429 - accuracy: 0.8971 - val_loss: 0.2260 - val_accuracy: 0.9051
# Epoch 87/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2420 - accuracy: 0.8983 - val_loss: 0.2190 - val_accuracy: 0.9104
# Epoch 88/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2407 - accuracy: 0.8981 - val_loss: 0.2185 - val_accuracy: 0.9079
# Epoch 89/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2415 - accuracy: 0.8989 - val_loss: 0.2174 - val_accuracy: 0.9095
# Epoch 90/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2410 - accuracy: 0.8979 - val_loss: 0.2158 - val_accuracy: 0.9107
# Epoch 91/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2389 - accuracy: 0.8986 - val_loss: 0.2188 - val_accuracy: 0.9086
# Epoch 92/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2404 - accuracy: 0.8979 - val_loss: 0.2197 - val_accuracy: 0.9074
# Epoch 93/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2380 - accuracy: 0.8985 - val_loss: 0.2173 - val_accuracy: 0.9100
# Epoch 94/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2395 - accuracy: 0.8974 - val_loss: 0.2185 - val_accuracy: 0.9079
# Epoch 95/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2382 - accuracy: 0.8980 - val_loss: 0.2186 - val_accuracy: 0.9082
# Epoch 96/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2395 - accuracy: 0.8968 - val_loss: 0.2127 - val_accuracy: 0.9132
# Epoch 97/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2385 - accuracy: 0.8959 - val_loss: 0.2266 - val_accuracy: 0.9030
# Epoch 98/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2402 - accuracy: 0.8972 - val_loss: 0.2159 - val_accuracy: 0.9098
# Epoch 99/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2397 - accuracy: 0.8996 - val_loss: 0.2131 - val_accuracy: 0.9102
# Epoch 100/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2389 - accuracy: 0.9015 - val_loss: 0.2136 - val_accuracy: 0.9119
# Epoch 101/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2377 - accuracy: 0.8962 - val_loss: 0.2213 - val_accuracy: 0.9072
# Epoch 102/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2387 - accuracy: 0.8989 - val_loss: 0.2162 - val_accuracy: 0.9114
# Epoch 103/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2387 - accuracy: 0.8992 - val_loss: 0.2113 - val_accuracy: 0.9128
# Epoch 104/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2373 - accuracy: 0.8983 - val_loss: 0.2143 - val_accuracy: 0.9109
# Epoch 105/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2383 - accuracy: 0.8996 - val_loss: 0.2134 - val_accuracy: 0.9125
# Epoch 106/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2368 - accuracy: 0.8999 - val_loss: 0.2133 - val_accuracy: 0.9114
# Epoch 107/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2367 - accuracy: 0.8995 - val_loss: 0.2178 - val_accuracy: 0.9100
# Epoch 108/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2372 - accuracy: 0.8979 - val_loss: 0.2185 - val_accuracy: 0.9065
# Epoch 109/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2373 - accuracy: 0.8986 - val_loss: 0.2136 - val_accuracy: 0.9125
# Epoch 110/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2365 - accuracy: 0.8988 - val_loss: 0.2128 - val_accuracy: 0.9107
# Epoch 111/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2349 - accuracy: 0.9000 - val_loss: 0.2169 - val_accuracy: 0.9095
# Epoch 112/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2373 - accuracy: 0.8989 - val_loss: 0.2234 - val_accuracy: 0.9054
# Epoch 113/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2387 - accuracy: 0.8984 - val_loss: 0.2149 - val_accuracy: 0.9086
# Epoch 114/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2369 - accuracy: 0.8993 - val_loss: 0.2162 - val_accuracy: 0.9102
# Epoch 115/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2355 - accuracy: 0.8990 - val_loss: 0.2215 - val_accuracy: 0.9072
# Epoch 116/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2349 - accuracy: 0.9003 - val_loss: 0.2233 - val_accuracy: 0.9061
# Epoch 117/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2363 - accuracy: 0.8988 - val_loss: 0.2181 - val_accuracy: 0.9119
# Epoch 118/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2335 - accuracy: 0.9003 - val_loss: 0.2131 - val_accuracy: 0.9128
# Epoch 119/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2343 - accuracy: 0.8996 - val_loss: 0.2194 - val_accuracy: 0.9077
# Epoch 120/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2383 - accuracy: 0.8987 - val_loss: 0.2157 - val_accuracy: 0.9098
# Epoch 121/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2376 - accuracy: 0.9002 - val_loss: 0.2173 - val_accuracy: 0.9095
# Epoch 122/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2348 - accuracy: 0.8998 - val_loss: 0.2191 - val_accuracy: 0.9088
# Epoch 123/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2343 - accuracy: 0.9007 - val_loss: 0.2141 - val_accuracy: 0.9107
# Epoch 124/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2352 - accuracy: 0.9001 - val_loss: 0.2211 - val_accuracy: 0.9081
# Epoch 125/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2330 - accuracy: 0.9002 - val_loss: 0.2166 - val_accuracy: 0.9093
# Epoch 126/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2342 - accuracy: 0.9017 - val_loss: 0.2182 - val_accuracy: 0.9091
# Epoch 127/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2322 - accuracy: 0.9012 - val_loss: 0.2186 - val_accuracy: 0.9088
# Epoch 128/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2353 - accuracy: 0.9005 - val_loss: 0.2148 - val_accuracy: 0.9114
# Epoch 129/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2349 - accuracy: 0.9007 - val_loss: 0.2161 - val_accuracy: 0.9086
# Epoch 130/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2342 - accuracy: 0.9013 - val_loss: 0.2171 - val_accuracy: 0.9093
# Epoch 131/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2335 - accuracy: 0.9006 - val_loss: 0.2135 - val_accuracy: 0.9118
# Epoch 132/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2346 - accuracy: 0.8992 - val_loss: 0.2184 - val_accuracy: 0.9084
# Epoch 133/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2336 - accuracy: 0.8986 - val_loss: 0.2245 - val_accuracy: 0.9075
# Epoch 134/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2335 - accuracy: 0.9012 - val_loss: 0.2157 - val_accuracy: 0.9121
# Epoch 135/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2350 - accuracy: 0.9004 - val_loss: 0.2141 - val_accuracy: 0.9084
# Epoch 136/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2349 - accuracy: 0.9004 - val_loss: 0.2167 - val_accuracy: 0.9098
# Epoch 137/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2352 - accuracy: 0.9009 - val_loss: 0.2186 - val_accuracy: 0.9089
# Epoch 138/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2354 - accuracy: 0.8995 - val_loss: 0.2109 - val_accuracy: 0.9107
# Epoch 139/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2332 - accuracy: 0.8992 - val_loss: 0.2166 - val_accuracy: 0.9126
# Epoch 140/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2329 - accuracy: 0.8997 - val_loss: 0.2140 - val_accuracy: 0.9128
# Epoch 141/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2316 - accuracy: 0.9006 - val_loss: 0.2128 - val_accuracy: 0.9116
# Epoch 142/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2312 - accuracy: 0.9008 - val_loss: 0.2162 - val_accuracy: 0.9102
# Epoch 143/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2325 - accuracy: 0.9006 - val_loss: 0.2133 - val_accuracy: 0.9125
# Epoch 144/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2323 - accuracy: 0.9001 - val_loss: 0.2140 - val_accuracy: 0.9096
# Epoch 145/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2356 - accuracy: 0.8997 - val_loss: 0.2122 - val_accuracy: 0.9128
# Epoch 146/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2302 - accuracy: 0.9010 - val_loss: 0.2137 - val_accuracy: 0.9105
# Epoch 147/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2311 - accuracy: 0.9019 - val_loss: 0.2202 - val_accuracy: 0.9070
# Epoch 148/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2320 - accuracy: 0.9014 - val_loss: 0.2139 - val_accuracy: 0.9109
# Epoch 149/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2320 - accuracy: 0.9027 - val_loss: 0.2204 - val_accuracy: 0.9104
# Epoch 150/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2308 - accuracy: 0.9017 - val_loss: 0.2177 - val_accuracy: 0.9088
# Epoch 151/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2349 - accuracy: 0.8999 - val_loss: 0.2165 - val_accuracy: 0.9081
# Epoch 152/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2314 - accuracy: 0.8996 - val_loss: 0.2211 - val_accuracy: 0.9054
# Epoch 153/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2285 - accuracy: 0.9014 - val_loss: 0.2123 - val_accuracy: 0.9125
# Epoch 154/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2313 - accuracy: 0.9003 - val_loss: 0.2101 - val_accuracy: 0.9128
# Epoch 155/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2313 - accuracy: 0.9018 - val_loss: 0.2149 - val_accuracy: 0.9107
# Epoch 156/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2330 - accuracy: 0.9031 - val_loss: 0.2157 - val_accuracy: 0.9107
# Epoch 157/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2296 - accuracy: 0.9023 - val_loss: 0.2123 - val_accuracy: 0.9125
# Epoch 158/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2324 - accuracy: 0.9031 - val_loss: 0.2154 - val_accuracy: 0.9091
# Epoch 159/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2324 - accuracy: 0.9014 - val_loss: 0.2214 - val_accuracy: 0.9072
# Epoch 160/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2329 - accuracy: 0.9010 - val_loss: 0.2150 - val_accuracy: 0.9114
# Epoch 161/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2289 - accuracy: 0.9026 - val_loss: 0.2142 - val_accuracy: 0.9121
# Epoch 162/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2284 - accuracy: 0.9041 - val_loss: 0.2158 - val_accuracy: 0.9118
# Epoch 163/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2310 - accuracy: 0.9013 - val_loss: 0.2148 - val_accuracy: 0.9096
# Epoch 164/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2301 - accuracy: 0.9015 - val_loss: 0.2171 - val_accuracy: 0.9093
# Epoch 165/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2296 - accuracy: 0.9014 - val_loss: 0.2170 - val_accuracy: 0.9082
# Epoch 166/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2280 - accuracy: 0.9042 - val_loss: 0.2145 - val_accuracy: 0.9093
# Epoch 167/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2304 - accuracy: 0.9024 - val_loss: 0.2170 - val_accuracy: 0.9089
# Epoch 168/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2329 - accuracy: 0.9006 - val_loss: 0.2136 - val_accuracy: 0.9100
# Epoch 169/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2296 - accuracy: 0.9020 - val_loss: 0.2118 - val_accuracy: 0.9137
# Epoch 170/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2285 - accuracy: 0.9028 - val_loss: 0.2161 - val_accuracy: 0.9100
# Epoch 171/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2269 - accuracy: 0.9041 - val_loss: 0.2162 - val_accuracy: 0.9102
# Epoch 172/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2284 - accuracy: 0.9021 - val_loss: 0.2155 - val_accuracy: 0.9095
# Epoch 173/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2267 - accuracy: 0.9033 - val_loss: 0.2156 - val_accuracy: 0.9121
# Epoch 174/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2286 - accuracy: 0.9035 - val_loss: 0.2172 - val_accuracy: 0.9070: 0s - loss: 0.2278 - accuracy
# Epoch 175/1000
# 228/228 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.90 - 1s 2ms/step - loss: 0.2273 - accuracy: 0.9031 - val_loss: 0.2166 - val_accuracy: 0.9091
# Epoch 176/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2293 - accuracy: 0.9021 - val_loss: 0.2159 - val_accuracy: 0.9082
# Epoch 177/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2297 - accuracy: 0.8999 - val_loss: 0.2157 - val_accuracy: 0.9118
# Epoch 178/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.9046 - val_loss: 0.2185 - val_accuracy: 0.9091
# Epoch 179/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2270 - accuracy: 0.9034 - val_loss: 0.2152 - val_accuracy: 0.9100
# Epoch 180/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9047 - val_loss: 0.2120 - val_accuracy: 0.9126
# Epoch 181/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2285 - accuracy: 0.9045 - val_loss: 0.2161 - val_accuracy: 0.9100
# Epoch 182/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2281 - accuracy: 0.9040 - val_loss: 0.2155 - val_accuracy: 0.9089
# Epoch 183/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2279 - accuracy: 0.9030 - val_loss: 0.2178 - val_accuracy: 0.9088
# Epoch 184/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2286 - accuracy: 0.9042 - val_loss: 0.2157 - val_accuracy: 0.9100
# Epoch 185/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9025 - val_loss: 0.2120 - val_accuracy: 0.9132
# Epoch 186/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9059 - val_loss: 0.2141 - val_accuracy: 0.9116
# Epoch 187/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2258 - accuracy: 0.9039 - val_loss: 0.2158 - val_accuracy: 0.9096
# Epoch 188/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9033 - val_loss: 0.2132 - val_accuracy: 0.9119
# Epoch 189/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9028 - val_loss: 0.2147 - val_accuracy: 0.9119
# Epoch 190/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2239 - accuracy: 0.9031 - val_loss: 0.2238 - val_accuracy: 0.9077
# Epoch 191/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9027 - val_loss: 0.2168 - val_accuracy: 0.9082
# Epoch 192/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9028 - val_loss: 0.2155 - val_accuracy: 0.9096
# Epoch 193/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2285 - accuracy: 0.9028 - val_loss: 0.2145 - val_accuracy: 0.9095
# Epoch 194/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2244 - accuracy: 0.9054 - val_loss: 0.2162 - val_accuracy: 0.9095
# Epoch 195/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9039 - val_loss: 0.2151 - val_accuracy: 0.9109
# Epoch 196/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.9028 - val_loss: 0.2147 - val_accuracy: 0.9118
# Epoch 197/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9015 - val_loss: 0.2185 - val_accuracy: 0.9114
# Epoch 198/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9038 - val_loss: 0.2148 - val_accuracy: 0.9104
# Epoch 199/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9048 - val_loss: 0.2150 - val_accuracy: 0.9125
# Epoch 200/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.9028 - val_loss: 0.2150 - val_accuracy: 0.9118
# Epoch 201/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9044 - val_loss: 0.2152 - val_accuracy: 0.9102
# Epoch 202/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2243 - accuracy: 0.9054 - val_loss: 0.2178 - val_accuracy: 0.9105
# Epoch 203/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2246 - accuracy: 0.9036 - val_loss: 0.2148 - val_accuracy: 0.9118
# Epoch 204/1000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9058 - val_loss: 0.2150 - val_accuracy: 0.9114
# Epoch 00204: early stopping

# %%
'''
# serialize model to JSON
model_json = model.to_json()
with open("Mstop_182_5_mchi_7_5.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("Mstop_182_5_mchi_7_5.h5")
print("Saved model to disk")
'''
# Out:
# Saved model to disk

# %%
def show_losses( histories ):
    plt.figure(figsize=(10,10))
    plt.xlabel('Epoch', fontsize=15)
    plt.ylabel('Loss' , fontsize=15)
    plt.tick_params(axis="y", labelsize=15)
    plt.tick_params(axis="x", labelsize=15)
    plt.title('Training Error by Epoch', fontsize=15)
    colors=[]
    do_acc=False
    for label,loss in histories:
        color = tuple(np.random.random(3))
        colors.append(color)
        l = label
        vl= label+" validation"
        if 'acc' in loss.history:
            l+=' (acc %2.4f)'% (loss.history['acc'][-1])
            do_acc = True
        if 'val_acc' in loss.history:
            vl+=' (val acc %2.4f)'% (loss.history['val_acc'][-1])
            do_acc = True
        plt.plot(loss.history['loss'], label=l, color=color)
        if 'val_loss' in loss.history:
            plt.plot(loss.history['val_loss'], lw=2, ls='dashed', label=vl, color=color)

    plt.legend(fontsize=15)
    #plt.yscale('log')
    plt.show()
    if not do_acc: return
    plt.figure(figsize=(10,10))
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    for i,(label,loss) in enumerate(histories):
        color = colors[i]
        if 'acc' in loss.history:
            plt.plot(loss.history['acc'], lw=2, label=label+" accuracy", color=color)
        if 'val_acc' in loss.history:
            plt.plot(loss.history['val_acc'], lw=2, ls='dashed', label=label+" validation accuracy", color=color)

    plt.show()

# %%
show_losses( [("Cross Entropy Loss S/B", hist)])

# %%
from sklearn.metrics import roc_curve
y_pred_train = model.predict(x_train).ravel()
y_pred_test  = model.predict(x_test).ravel()

fpr_keras_train, tpr_keras_train, thresholds_keras = roc_curve(y_train, y_pred_train)
fpr_keras_test , tpr_keras_test , thresholds_keras = roc_curve(y_test , y_pred_test)

# %%
from sklearn.metrics import auc
auc_keras_test  = auc(fpr_keras_test, tpr_keras_test)
auc_keras_train = auc(fpr_keras_train, tpr_keras_train)

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras_train, tpr_keras_train, label='Training set (AUC = {:.3f})'.format(auc_keras_train))
plt.plot(fpr_keras_test , tpr_keras_test , label='Test set (AUC = {:.3f})'.format(auc_keras_test))
plt.tick_params(axis="y", labelsize=17)
plt.tick_params(axis="x", labelsize=17)
plt.xlabel('False positive rate', fontsize=15)
plt.ylabel('True positive rate' , fontsize=15)
plt.title('Mstop_242.5 mchi_60 ROC curve', fontsize=17)
plt.legend(loc='lower right', fontsize=17)
plt.grid()
plt.savefig('ROC Mstop 242.5 Mchi 60.jpg')
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(figsize=(10,10))
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras_train, tpr_keras_train, label='Training set (area = {:.3f})'.format(auc_keras_train))
plt.plot(fpr_keras_test , tpr_keras_test , label='Test set (area = {:.3f})'.format(auc_keras_test))
plt.ylabel('True positive rate' , fontsize=17)
plt.xlabel('False positive rate', fontsize=17)
plt.tick_params(axis="y", labelsize=15)
plt.tick_params(axis="x", labelsize=15)
plt.title('ROC curve (zoomed in at top left)', fontsize=17)
plt.legend(loc='best', fontsize=17)
plt.grid()
plt.show()

# %%
tt_pred  = model.predict(tt_df[30000:]) 
st_pred  = model.predict(st_df[5000:]) 
sat_pred = model.predict(sat_df[5000:]) 
vv_pred  = model.predict(vv_df[2000:]) 
si_pred  = model.predict(sig_df[15000:])

# %%
st_list = [st_pred, sat_pred]
st_arr  = np.array(st_list)

# %%
plt.figure(figsize=(10,10))
plt.tick_params(axis="y", labelsize=14)
plt.tick_params(axis="x", labelsize=14)
plt.hist(tt_pred, bins=15, alpha=0.3, label='ttbar')
plt.hist(si_pred, bins=15, alpha=0.3, label='SUSY Mstop 242.5 Mchi 60')
plt.hist(st_pred, bins=15, alpha=0.3, label='Single Top')
plt.hist(vv_pred, bins=15, alpha=0.3, label='Diboson ')
#plt.hist(sat_pred, bins=15, alpha=0.3, label='Single Antitop')
plt.yscale('log')
plt.xlim(0,1)
plt.xlabel('DNN score', fontsize=15)
plt.ylabel('Number of events (log scale)', fontsize=15)
plt.grid()
plt.legend(loc='best', fontsize=15)
plt.savefig('DNN score Mstop_242.5 Mchi_60.jpg')

# %%
np.savetxt('Mstop_182_5_mchi_7_5_SUSY_pred.txt', si_pred)
np.savetxt('Mstop_182_5_mchi_7_5_tt_pred.txt'  , tt_pred)
np.savetxt('Mstop_182_5_mchi_7_5_st_pred.txt'  , st_pred)
np.savetxt('Mstop_182_5_mchi_7_5_sat_pred.txt' , sat_pred)
np.savetxt('Mstop_182_5_mchi_7_5_vv_pred.txt'  , vv_pred)

# %%
c0 = 'C0'
c1 = 'C1'
plt.figure(figsize=(10,9))
plt.tick_params(axis="y", labelsize=14)
plt.tick_params(axis="x", labelsize=14)
plt.hist(y_pred_train[y_train == 0], bins=15, label='SM Training set', histtype='step', linestyle='solid', linewidth=1.5, density=True, color=c0)
plt.hist(y_pred_test[y_test == 0]  , bins=15, label='SM Test set'    , alpha=0.3, linewidth=1.5, density=True , color=c0)
plt.hist(y_pred_train[y_train == 1], bins=15, label='SUSY Training set', histtype='step' , linestyle='solid', linewidth=1.5, density=True, color=c1)
plt.hist(y_pred_test[y_test == 1]  , bins=15, label='SUSY Test set ', alpha=0.3, linewidth=1.5, density=True, color=c1)

plt.yscale('log')
plt.ylim(0.1, 30)
plt.xlim(0,1)
plt.xlabel('DNN score (Mstop_242.5 Mchi_60)', fontsize=17)
plt.ylabel('Arbitrary units', fontsize=17)
plt.legend(loc='upper center', fontsize=17)
#plt.savefig('Train vs test Mstop_242.5 Mchi_60.jpg')

# %%
def CorrMtx(df, dropDuplicates = True):

    # Your dataset is already a correlation matrix.
    # If you have a dateset where you need to include the calculation
    # of a correlation matrix, just uncomment the line below:
    # df = df.corr()
    sns.set(font_scale=1.4)
    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(15, 12))

    # Add diverging colormap from red to blue
    #cmap = sns.diverging_palette(250, 10, as_cmap=True)
    #cmap  = sns.color_palette("coolwarm")
    cmap = sns.diverging_palette(0,255,sep=1, as_cmap=True)
                                 
    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        hm = sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax, vmin=-1, vmax=1)
        plt.title('Correlation matrix for input features', fontsize=30)
        plt.savefig('ip_features_corr.png')
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax, vmin=-1, vmax=1)

# %%
CorrMtx(corr, dropDuplicates = True)

# %%
len(sig_df)
# Out:
# 133048

# %%
len(st_df)
# Out:
# 126598

# %%
len(sat_df)
# Out:
# 124778

# %%
len(tt_df)
# Out:
# 1507877

# %%
len(vv_df)
# Out:
# 19169
