# %%
import ROOT
import uproot
import numpy as np
import pandas as pd
import torch 
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.22/00

# %%
sig_df = pd.read_pickle('DNN_ips/SUSY_Mstop_227_5_mchi_60.pkl')
tt_df  = pd.read_pickle('DNN_ips/ttbar.pkl')
vv_df  = pd.read_pickle('DNN_ips/VV.pkl')
st_df  = pd.read_pickle('DNN_ips/Single_top.pkl')
sat_df = pd.read_pickle('DNN_ips/Single_antitop.pkl')

# %%
Pol_rw  = np.loadtxt('txt_files/SUSY_weights_mstop_175_mchi_7_5_Pol_minus1.txt')
Ecom_rw = np.loadtxt('txt_files/SUSY_Ecom_rw.txt')
Rw      = Pol_rw * Ecom_rw

# %%
# Standardize
sig_mean = sig_df.mean()
sig_std  = sig_df.std()

tt_mean = tt_df.mean()
tt_std  = tt_df.std()

st_mean = st_df.mean()
st_std  = st_df.std()

vv_mean = vv_df.mean()
vv_std  = vv_df.std()

sat_mean = sat_df.mean()
sat_std  = sat_df.std()

sig_df = (sig_df - sig_mean)/ sig_std
tt_df  = (tt_df  - tt_mean)/ tt_std
st_df  = (st_df  - st_mean)/ st_std
vv_df  = (vv_df  - vv_mean)/ vv_std
sat_df = (sat_df  - sat_mean)/ sat_std

# %%
# Set both to equal sizes 
# Reducing the bkg dataframe size

sig_df_train = sig_df[1:15000]
tt_df_train  = tt_df[1:30000]
st_df_train  = st_df[1:5000]
sat_df_train = sat_df[1:5000]
vv_df_train  = vv_df[1:2000]

# %%
bkgList = [tt_df_train, st_df_train, sat_df_train, vv_df_train]  # List of your dataframes

bkg_df_train = pd.concat(bkgList)

signal = sig_df_train.values
bkg    = bkg_df_train.values

sig_label = np.ones(len(signal))
bkg_label = np.zeros(len(bkg))

data      = np.concatenate((signal,bkg))
label     = np.concatenate((sig_label,bkg_label))

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=2, shuffle=True)
skf.get_n_splits(data, label)
skf.split(data, label)
# Out:
# <generator object _BaseKFold.split at 0x7ff5ef570ba0>

# %%
for train_index, test_index in skf.split(data, label):
    print("TRAIN:", train_index, "TEST:", test_index)
    x_train, x_test = data[train_index], data[test_index]
    y_train, y_test = label[train_index], label[test_index]
# Out:
# TRAIN: [    3     5     6 ... 56990 56991 56993] TEST: [    0     1     2 ... 56988 56992 56994]
# TRAIN: [    0     1     2 ... 56988 56992 56994] TEST: [    3     5     6 ... 56990 56991 56993]

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout
from skopt import gp_minimize

model = Sequential()
model.add(Dense(100, input_dim = 19  ,activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(100, input_dim = 100 ,activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2000
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 12,201
# Trainable params: 12,201
# Non-trainable params: 0
# _________________________________________________________________
# 2021-02-26 01:35:05.630052: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-02-26 01:35:05.676869: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff5f3d68d90 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-26 01:35:05.676888: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
hist = model.fit(x_train, y_train, batch_size=100, epochs=1000,verbose=1, shuffle=True, validation_split=0.2,
                  callbacks=[EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='min'),
                  ModelCheckpoint(filepath='model.h5', verbose=0)])
# Out:
# Epoch 1/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.6061 - accuracy: 0.7090 - val_loss: 0.5769 - val_accuracy: 0.7404
# Epoch 2/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5873 - accuracy: 0.7348 - val_loss: 0.5807 - val_accuracy: 0.7404
# Epoch 3/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5843 - accuracy: 0.7351 - val_loss: 0.5766 - val_accuracy: 0.7404
# Epoch 4/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5826 - accuracy: 0.7360 - val_loss: 0.5741 - val_accuracy: 0.7404
# Epoch 5/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5797 - accuracy: 0.7357 - val_loss: 0.5716 - val_accuracy: 0.7404
# Epoch 6/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5791 - accuracy: 0.7359 - val_loss: 0.5725 - val_accuracy: 0.7405
# Epoch 7/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5766 - accuracy: 0.7354 - val_loss: 0.5701 - val_accuracy: 0.7404
# Epoch 8/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5758 - accuracy: 0.7360 - val_loss: 0.5685 - val_accuracy: 0.7404
# Epoch 9/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5743 - accuracy: 0.7358 - val_loss: 0.5669 - val_accuracy: 0.7405
# Epoch 10/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.5708 - accuracy: 0.7362 - val_loss: 0.5613 - val_accuracy: 0.7409
# Epoch 11/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5645 - accuracy: 0.7374 - val_loss: 0.5492 - val_accuracy: 0.7414
# Epoch 12/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5451 - accuracy: 0.7437 - val_loss: 0.5134 - val_accuracy: 0.7553
# Epoch 13/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.4950 - accuracy: 0.7713 - val_loss: 0.4226 - val_accuracy: 0.8123
# Epoch 14/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.4111 - accuracy: 0.8216 - val_loss: 0.3335 - val_accuracy: 0.8602
# Epoch 15/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.3477 - accuracy: 0.8533 - val_loss: 0.2844 - val_accuracy: 0.8812
# Epoch 16/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.3139 - accuracy: 0.8645 - val_loss: 0.2573 - val_accuracy: 0.8963
# Epoch 17/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2968 - accuracy: 0.8701 - val_loss: 0.2503 - val_accuracy: 0.8951
# Epoch 18/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2858 - accuracy: 0.8788 - val_loss: 0.2476 - val_accuracy: 0.8967
# Epoch 19/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2788 - accuracy: 0.8804 - val_loss: 0.2438 - val_accuracy: 0.8965
# Epoch 20/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2742 - accuracy: 0.8818 - val_loss: 0.2365 - val_accuracy: 0.8982
# Epoch 21/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2727 - accuracy: 0.8823 - val_loss: 0.2272 - val_accuracy: 0.9082
# Epoch 22/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2652 - accuracy: 0.8876 - val_loss: 0.2269 - val_accuracy: 0.9053
# Epoch 23/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2644 - accuracy: 0.8857 - val_loss: 0.2217 - val_accuracy: 0.9104
# Epoch 24/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2607 - accuracy: 0.8885 - val_loss: 0.2257 - val_accuracy: 0.9054
# Epoch 25/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2591 - accuracy: 0.8911 - val_loss: 0.2261 - val_accuracy: 0.9018
# Epoch 26/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2530 - accuracy: 0.8916 - val_loss: 0.2218 - val_accuracy: 0.9086
# Epoch 27/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2506 - accuracy: 0.8935 - val_loss: 0.2219 - val_accuracy: 0.9068
# Epoch 28/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2537 - accuracy: 0.8931 - val_loss: 0.2190 - val_accuracy: 0.9095
# Epoch 29/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2524 - accuracy: 0.8916 - val_loss: 0.2204 - val_accuracy: 0.9053
# Epoch 30/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2501 - accuracy: 0.8942 - val_loss: 0.2184 - val_accuracy: 0.9074
# Epoch 31/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2491 - accuracy: 0.8938 - val_loss: 0.2167 - val_accuracy: 0.9086
# Epoch 32/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2488 - accuracy: 0.8936 - val_loss: 0.2121 - val_accuracy: 0.9111
# Epoch 33/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2465 - accuracy: 0.8947 - val_loss: 0.2125 - val_accuracy: 0.9139
# Epoch 34/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2440 - accuracy: 0.8963 - val_loss: 0.2125 - val_accuracy: 0.9112
# Epoch 35/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2442 - accuracy: 0.8949 - val_loss: 0.2120 - val_accuracy: 0.9086
# Epoch 36/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2467 - accuracy: 0.8956 - val_loss: 0.2099 - val_accuracy: 0.9135
# Epoch 37/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2405 - accuracy: 0.8966 - val_loss: 0.2141 - val_accuracy: 0.9125
# Epoch 38/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2390 - accuracy: 0.8964 - val_loss: 0.2100 - val_accuracy: 0.9118
# Epoch 39/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2390 - accuracy: 0.8969 - val_loss: 0.2086 - val_accuracy: 0.9123
# Epoch 40/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2378 - accuracy: 0.8977 - val_loss: 0.2088 - val_accuracy: 0.9116
# Epoch 41/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2394 - accuracy: 0.8971 - val_loss: 0.2076 - val_accuracy: 0.9144
# Epoch 42/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2372 - accuracy: 0.8991 - val_loss: 0.2103 - val_accuracy: 0.9102
# Epoch 43/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2352 - accuracy: 0.8991 - val_loss: 0.2086 - val_accuracy: 0.9128
# Epoch 44/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2359 - accuracy: 0.8985 - val_loss: 0.2138 - val_accuracy: 0.9109
# Epoch 45/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2345 - accuracy: 0.8980 - val_loss: 0.2060 - val_accuracy: 0.9135
# Epoch 46/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2309 - accuracy: 0.9014 - val_loss: 0.2073 - val_accuracy: 0.9118
# Epoch 47/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2337 - accuracy: 0.8990 - val_loss: 0.2091 - val_accuracy: 0.9126
# Epoch 48/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2330 - accuracy: 0.8985 - val_loss: 0.2126 - val_accuracy: 0.9118
# Epoch 49/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2346 - accuracy: 0.9006 - val_loss: 0.2073 - val_accuracy: 0.9112
# Epoch 50/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2316 - accuracy: 0.9000 - val_loss: 0.2098 - val_accuracy: 0.9123
# Epoch 51/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2345 - accuracy: 0.8993 - val_loss: 0.2051 - val_accuracy: 0.9144
# Epoch 52/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2305 - accuracy: 0.9002 - val_loss: 0.2107 - val_accuracy: 0.9105
# Epoch 53/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2331 - accuracy: 0.9003 - val_loss: 0.2062 - val_accuracy: 0.9149
# Epoch 54/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2293 - accuracy: 0.9030 - val_loss: 0.2068 - val_accuracy: 0.9130
# Epoch 55/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2304 - accuracy: 0.9006 - val_loss: 0.2083 - val_accuracy: 0.9133
# Epoch 56/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2304 - accuracy: 0.9006 - val_loss: 0.2043 - val_accuracy: 0.9133
# Epoch 57/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2292 - accuracy: 0.9007 - val_loss: 0.2053 - val_accuracy: 0.9135
# Epoch 58/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2287 - accuracy: 0.9037 - val_loss: 0.2062 - val_accuracy: 0.9142
# Epoch 59/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2266 - accuracy: 0.9051 - val_loss: 0.2089 - val_accuracy: 0.9142
# Epoch 60/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2298 - accuracy: 0.9019 - val_loss: 0.2054 - val_accuracy: 0.9139
# Epoch 61/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2290 - accuracy: 0.9015 - val_loss: 0.2034 - val_accuracy: 0.9163
# Epoch 62/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2254 - accuracy: 0.9036 - val_loss: 0.2017 - val_accuracy: 0.9160
# Epoch 63/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2300 - accuracy: 0.9010 - val_loss: 0.2066 - val_accuracy: 0.9112
# Epoch 64/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2252 - accuracy: 0.9024 - val_loss: 0.2070 - val_accuracy: 0.9140
# Epoch 65/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2286 - accuracy: 0.9014 - val_loss: 0.2024 - val_accuracy: 0.9158
# Epoch 66/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2271 - accuracy: 0.9023 - val_loss: 0.2026 - val_accuracy: 0.9153
# Epoch 67/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2267 - accuracy: 0.9023 - val_loss: 0.2080 - val_accuracy: 0.9135
# Epoch 68/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2247 - accuracy: 0.9030 - val_loss: 0.2000 - val_accuracy: 0.9179
# Epoch 69/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2256 - accuracy: 0.9031 - val_loss: 0.2034 - val_accuracy: 0.9154
# Epoch 70/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2243 - accuracy: 0.9028 - val_loss: 0.2008 - val_accuracy: 0.9154
# Epoch 71/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2256 - accuracy: 0.9013 - val_loss: 0.2030 - val_accuracy: 0.9149
# Epoch 72/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2274 - accuracy: 0.9003 - val_loss: 0.2044 - val_accuracy: 0.9133
# Epoch 73/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2239 - accuracy: 0.9044 - val_loss: 0.2103 - val_accuracy: 0.9114
# Epoch 74/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2246 - accuracy: 0.9035 - val_loss: 0.1983 - val_accuracy: 0.9191
# Epoch 75/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2247 - accuracy: 0.9021 - val_loss: 0.2047 - val_accuracy: 0.9128
# Epoch 76/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2244 - accuracy: 0.9031 - val_loss: 0.2015 - val_accuracy: 0.9147
# Epoch 77/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2220 - accuracy: 0.9043 - val_loss: 0.2025 - val_accuracy: 0.9163
# Epoch 78/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2242 - accuracy: 0.9015 - val_loss: 0.2015 - val_accuracy: 0.9132
# Epoch 79/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2240 - accuracy: 0.9026 - val_loss: 0.2038 - val_accuracy: 0.9105
# Epoch 80/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2245 - accuracy: 0.9030 - val_loss: 0.2031 - val_accuracy: 0.9126
# Epoch 81/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2239 - accuracy: 0.9054 - val_loss: 0.2053 - val_accuracy: 0.9125
# Epoch 82/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2225 - accuracy: 0.9050 - val_loss: 0.2031 - val_accuracy: 0.9158
# Epoch 83/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2238 - accuracy: 0.9028 - val_loss: 0.2012 - val_accuracy: 0.9189
# Epoch 84/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2215 - accuracy: 0.9049 - val_loss: 0.2046 - val_accuracy: 0.9112
# Epoch 85/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2226 - accuracy: 0.9056 - val_loss: 0.2031 - val_accuracy: 0.9142
# Epoch 86/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2222 - accuracy: 0.9045 - val_loss: 0.2063 - val_accuracy: 0.9130
# Epoch 87/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2206 - accuracy: 0.9054 - val_loss: 0.2006 - val_accuracy: 0.9153
# Epoch 88/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2237 - accuracy: 0.9020 - val_loss: 0.2007 - val_accuracy: 0.9168
# Epoch 89/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2206 - accuracy: 0.9048 - val_loss: 0.2023 - val_accuracy: 0.9154
# Epoch 90/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2202 - accuracy: 0.9056 - val_loss: 0.1973 - val_accuracy: 0.9177
# Epoch 91/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2228 - accuracy: 0.9022 - val_loss: 0.1978 - val_accuracy: 0.9174
# Epoch 92/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2211 - accuracy: 0.9045 - val_loss: 0.2052 - val_accuracy: 0.9125
# Epoch 93/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2208 - accuracy: 0.9044 - val_loss: 0.2007 - val_accuracy: 0.9172
# Epoch 94/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2191 - accuracy: 0.9061 - val_loss: 0.2030 - val_accuracy: 0.9172
# Epoch 95/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2232 - accuracy: 0.9045 - val_loss: 0.2032 - val_accuracy: 0.9132
# Epoch 96/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2212 - accuracy: 0.9040 - val_loss: 0.2057 - val_accuracy: 0.9135
# Epoch 97/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2211 - accuracy: 0.9061 - val_loss: 0.2006 - val_accuracy: 0.9172
# Epoch 98/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2207 - accuracy: 0.9046 - val_loss: 0.2048 - val_accuracy: 0.9172
# Epoch 99/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2196 - accuracy: 0.9048 - val_loss: 0.2012 - val_accuracy: 0.9142
# Epoch 100/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2217 - accuracy: 0.9042 - val_loss: 0.2046 - val_accuracy: 0.9140
# Epoch 101/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2209 - accuracy: 0.9051 - val_loss: 0.2146 - val_accuracy: 0.9098
# Epoch 102/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2220 - accuracy: 0.9049 - val_loss: 0.2095 - val_accuracy: 0.9107
# Epoch 103/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2228 - accuracy: 0.9031 - val_loss: 0.2009 - val_accuracy: 0.9165
# Epoch 104/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2204 - accuracy: 0.9044 - val_loss: 0.2024 - val_accuracy: 0.9153
# Epoch 105/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2168 - accuracy: 0.9072 - val_loss: 0.2006 - val_accuracy: 0.9156
# Epoch 106/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2200 - accuracy: 0.9067 - val_loss: 0.2025 - val_accuracy: 0.9140
# Epoch 107/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2201 - accuracy: 0.9063 - val_loss: 0.2017 - val_accuracy: 0.9128
# Epoch 108/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2188 - accuracy: 0.9067 - val_loss: 0.2046 - val_accuracy: 0.9130
# Epoch 109/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2188 - accuracy: 0.9062 - val_loss: 0.2006 - val_accuracy: 0.9177
# Epoch 110/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2187 - accuracy: 0.9057 - val_loss: 0.1997 - val_accuracy: 0.9153
# Epoch 111/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2196 - accuracy: 0.9043 - val_loss: 0.1976 - val_accuracy: 0.9196
# Epoch 112/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2191 - accuracy: 0.9045 - val_loss: 0.2000 - val_accuracy: 0.9153
# Epoch 113/1000
# 228/228 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.90 - 1s 4ms/step - loss: 0.2180 - accuracy: 0.9049 - val_loss: 0.2034 - val_accuracy: 0.9139
# Epoch 114/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2182 - accuracy: 0.9055 - val_loss: 0.2051 - val_accuracy: 0.9133
# Epoch 115/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2179 - accuracy: 0.9063 - val_loss: 0.1998 - val_accuracy: 0.9181
# Epoch 116/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2203 - accuracy: 0.9030 - val_loss: 0.2052 - val_accuracy: 0.9156
# Epoch 117/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2212 - accuracy: 0.9041 - val_loss: 0.1999 - val_accuracy: 0.9182
# Epoch 118/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2210 - accuracy: 0.9043 - val_loss: 0.1999 - val_accuracy: 0.9149
# Epoch 119/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2173 - accuracy: 0.9069 - val_loss: 0.1991 - val_accuracy: 0.9165
# Epoch 120/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2173 - accuracy: 0.9056 - val_loss: 0.1994 - val_accuracy: 0.9174
# Epoch 121/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2161 - accuracy: 0.9078 - val_loss: 0.2023 - val_accuracy: 0.9158
# Epoch 122/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2207 - accuracy: 0.9050 - val_loss: 0.1991 - val_accuracy: 0.9188
# Epoch 123/1000
# 228/228 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.90 - 1s 4ms/step - loss: 0.2176 - accuracy: 0.9057 - val_loss: 0.2007 - val_accuracy: 0.9160
# Epoch 124/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2184 - accuracy: 0.9056 - val_loss: 0.2006 - val_accuracy: 0.9139
# Epoch 125/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2186 - accuracy: 0.9052 - val_loss: 0.2005 - val_accuracy: 0.9172
# Epoch 126/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2174 - accuracy: 0.9066 - val_loss: 0.1983 - val_accuracy: 0.9160
# Epoch 127/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2151 - accuracy: 0.9067 - val_loss: 0.2009 - val_accuracy: 0.9133
# Epoch 128/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2197 - accuracy: 0.9056 - val_loss: 0.1978 - val_accuracy: 0.9167
# Epoch 129/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2170 - accuracy: 0.9066 - val_loss: 0.1977 - val_accuracy: 0.9181
# Epoch 130/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2149 - accuracy: 0.9076 - val_loss: 0.1991 - val_accuracy: 0.9168
# Epoch 131/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2188 - accuracy: 0.9058 - val_loss: 0.1987 - val_accuracy: 0.9175
# Epoch 132/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2160 - accuracy: 0.9056 - val_loss: 0.1981 - val_accuracy: 0.9184
# Epoch 133/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2168 - accuracy: 0.9065 - val_loss: 0.1993 - val_accuracy: 0.9172
# Epoch 134/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2161 - accuracy: 0.9070 - val_loss: 0.1993 - val_accuracy: 0.9156
# Epoch 135/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2168 - accuracy: 0.9064 - val_loss: 0.1959 - val_accuracy: 0.9186
# Epoch 136/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2167 - accuracy: 0.9060 - val_loss: 0.2018 - val_accuracy: 0.9168
# Epoch 137/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2158 - accuracy: 0.9062 - val_loss: 0.2020 - val_accuracy: 0.9149
# Epoch 138/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2175 - accuracy: 0.9064 - val_loss: 0.2001 - val_accuracy: 0.9175
# Epoch 139/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2154 - accuracy: 0.9071 - val_loss: 0.2006 - val_accuracy: 0.9144
# Epoch 140/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2151 - accuracy: 0.9066 - val_loss: 0.2025 - val_accuracy: 0.9132
# Epoch 141/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2158 - accuracy: 0.9071 - val_loss: 0.1971 - val_accuracy: 0.9193
# Epoch 142/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2155 - accuracy: 0.9068 - val_loss: 0.1990 - val_accuracy: 0.9161
# Epoch 143/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2149 - accuracy: 0.9061 - val_loss: 0.1984 - val_accuracy: 0.9174
# Epoch 144/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2160 - accuracy: 0.9076 - val_loss: 0.2012 - val_accuracy: 0.9160
# Epoch 145/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2133 - accuracy: 0.9080 - val_loss: 0.2004 - val_accuracy: 0.9161
# Epoch 146/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2165 - accuracy: 0.9038 - val_loss: 0.2092 - val_accuracy: 0.9109
# Epoch 147/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2150 - accuracy: 0.9068 - val_loss: 0.1976 - val_accuracy: 0.9174
# Epoch 148/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2143 - accuracy: 0.9068 - val_loss: 0.2015 - val_accuracy: 0.9165
# Epoch 149/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2151 - accuracy: 0.9069 - val_loss: 0.1983 - val_accuracy: 0.9172
# Epoch 150/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2149 - accuracy: 0.9066 - val_loss: 0.1997 - val_accuracy: 0.9158
# Epoch 151/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2142 - accuracy: 0.9091 - val_loss: 0.1979 - val_accuracy: 0.9177
# Epoch 152/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2149 - accuracy: 0.9069 - val_loss: 0.1999 - val_accuracy: 0.9160
# Epoch 153/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2137 - accuracy: 0.9093 - val_loss: 0.2030 - val_accuracy: 0.9146
# Epoch 154/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2132 - accuracy: 0.9089 - val_loss: 0.1989 - val_accuracy: 0.9181
# Epoch 155/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2130 - accuracy: 0.9075 - val_loss: 0.1993 - val_accuracy: 0.9156
# Epoch 156/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2116 - accuracy: 0.9096 - val_loss: 0.2006 - val_accuracy: 0.9165
# Epoch 157/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2109 - accuracy: 0.9085 - val_loss: 0.1993 - val_accuracy: 0.9153
# Epoch 158/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2149 - accuracy: 0.9092 - val_loss: 0.2036 - val_accuracy: 0.9139
# Epoch 159/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2130 - accuracy: 0.9089 - val_loss: 0.2003 - val_accuracy: 0.9161
# Epoch 160/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2129 - accuracy: 0.9088 - val_loss: 0.2014 - val_accuracy: 0.9163
# Epoch 161/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2140 - accuracy: 0.9060 - val_loss: 0.2009 - val_accuracy: 0.9156
# Epoch 162/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2131 - accuracy: 0.9089 - val_loss: 0.2006 - val_accuracy: 0.9149
# Epoch 163/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2113 - accuracy: 0.9093 - val_loss: 0.1987 - val_accuracy: 0.9172
# Epoch 164/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2171 - accuracy: 0.9067 - val_loss: 0.1992 - val_accuracy: 0.9160
# Epoch 165/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2131 - accuracy: 0.9089 - val_loss: 0.2021 - val_accuracy: 0.9182
# Epoch 166/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2097 - accuracy: 0.9098 - val_loss: 0.2013 - val_accuracy: 0.9139
# Epoch 167/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2132 - accuracy: 0.9082 - val_loss: 0.1987 - val_accuracy: 0.9156
# Epoch 168/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2128 - accuracy: 0.9097 - val_loss: 0.2000 - val_accuracy: 0.9158
# Epoch 169/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2124 - accuracy: 0.9076 - val_loss: 0.2003 - val_accuracy: 0.9158
# Epoch 170/1000
# 228/228 [==============================] - 1s 4ms/step - loss: 0.2123 - accuracy: 0.9087 - val_loss: 0.2016 - val_accuracy: 0.9154
# Epoch 171/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2104 - accuracy: 0.9083 - val_loss: 0.2010 - val_accuracy: 0.9146
# Epoch 172/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2115 - accuracy: 0.9083 - val_loss: 0.1979 - val_accuracy: 0.9170
# Epoch 173/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2119 - accuracy: 0.9089 - val_loss: 0.1974 - val_accuracy: 0.9175
# Epoch 174/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2123 - accuracy: 0.9068 - val_loss: 0.2039 - val_accuracy: 0.9144
# Epoch 175/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2122 - accuracy: 0.9085 - val_loss: 0.2019 - val_accuracy: 0.9146
# Epoch 176/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2101 - accuracy: 0.9094 - val_loss: 0.2018 - val_accuracy: 0.9167
# Epoch 177/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2094 - accuracy: 0.9105 - val_loss: 0.1991 - val_accuracy: 0.9179
# Epoch 178/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2125 - accuracy: 0.9092 - val_loss: 0.2079 - val_accuracy: 0.9126
# Epoch 179/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2011 - val_accuracy: 0.9140
# Epoch 180/1000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2100 - accuracy: 0.9099 - val_loss: 0.2019 - val_accuracy: 0.9156
# Epoch 181/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2116 - accuracy: 0.9081 - val_loss: 0.1988 - val_accuracy: 0.9172
# Epoch 182/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2116 - accuracy: 0.9092 - val_loss: 0.2023 - val_accuracy: 0.9156
# Epoch 183/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2097 - accuracy: 0.9102 - val_loss: 0.2013 - val_accuracy: 0.9146
# Epoch 184/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2109 - accuracy: 0.9089 - val_loss: 0.2016 - val_accuracy: 0.9140
# Epoch 185/1000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2102 - accuracy: 0.9088 - val_loss: 0.2052 - val_accuracy: 0.9116
# Epoch 00185: early stopping

# %%
'''
# serialize model to JSON
model_json = model.to_json()
with open("Mstop_182_5_mchi_7_5.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("Mstop_182_5_mchi_7_5.h5")
print("Saved model to disk")
'''
# Out:
# Saved model to disk

# %%
def show_losses( histories ):
    plt.figure(figsize=(10,10))
    plt.xlabel('Epoch', fontsize=17)
    plt.ylabel('Loss' , fontsize=17)
    plt.tick_params(axis="y", labelsize=15)
    plt.tick_params(axis="x", labelsize=15)
    plt.title('Cross Entropy Loss by Epoch', fontsize=17)
    color='C0'
    do_acc=False
    for label,loss in histories:
        #color = tuple(np.random.random(3))
        #colors.append(color)
        l = 'Training set loss'
        vl= 'Validation set loss'
        if 'acc' in loss.history:
            l+=' (acc %2.4f)'% (loss.history['acc'][-1])
            do_acc = True
        if 'val_acc' in loss.history:
            vl+=' (val acc %2.4f)'% (loss.history['val_acc'][-1])
            do_acc = True
        plt.plot(loss.history['loss'], label=l, color=color)
        if 'val_loss' in loss.history:
            plt.plot(loss.history['val_loss'], lw=2, ls='dashed', label=vl, color=color)

    plt.legend(fontsize=17)
    #plt.yscale('log')
    plt.show()
    #if not do_acc: return
    plt.figure(figsize=(10,10))
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    for i,(label,loss) in enumerate(histories):
        #color = colors[i]
        if 'acc' in loss.history:
            plt.plot(loss.history['acc'], lw=2, label=label+" accuracy", color=color)
        if 'val_acc' in loss.history:
            plt.plot(loss.history['val_acc'], lw=2, ls='dashed', label=label+" validation accuracy", color=color)

    plt.show()

# %%
show_losses( [("Binary Cross Entropy Loss", hist)])

# %%
from sklearn.metrics import roc_curve
y_pred_train = model.predict(x_train).ravel()
y_pred_test  = model.predict(x_test).ravel()

fpr_keras_train, tpr_keras_train, thresholds_keras = roc_curve(y_train, y_pred_train)
fpr_keras_test , tpr_keras_test , thresholds_keras = roc_curve(y_test , y_pred_test)

# %%
from sklearn.metrics import auc
auc_keras_test  = auc(fpr_keras_test, tpr_keras_test)
auc_keras_train = auc(fpr_keras_train, tpr_keras_train)

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras_train, tpr_keras_train, label='Training set (AUC = {:.3f})'.format(auc_keras_train))
plt.plot(fpr_keras_test , tpr_keras_test , label='Test set (AUC = {:.3f})'.format(auc_keras_test))
plt.tick_params(axis="y", labelsize=17)
plt.tick_params(axis="x", labelsize=17)
plt.xlabel('False positive rate', fontsize=15)
plt.ylabel('True positive rate' , fontsize=15)
plt.title('Mstop_227.5 mchi_60 ROC curve', fontsize=17)
plt.legend(loc='lower right', fontsize=17)
plt.grid()
plt.savefig('ROC Mstop 227.5 Mchi 60.jpg')
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(figsize=(10,10))
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras_train, tpr_keras_train, label='Training set (area = {:.3f})'.format(auc_keras_train))
plt.plot(fpr_keras_test , tpr_keras_test , label='Test set (area = {:.3f})'.format(auc_keras_test))
plt.ylabel('True positive rate' , fontsize=17)
plt.xlabel('False positive rate', fontsize=17)
plt.tick_params(axis="y", labelsize=15)
plt.tick_params(axis="x", labelsize=15)
plt.title('ROC curve (zoomed in at top left)', fontsize=17)
plt.legend(loc='best', fontsize=17)
plt.grid()
plt.show()

# %%
tt_pred  = model.predict(tt_df[30000:]) 
st_pred  = model.predict(st_df[5000:]) 
sat_pred = model.predict(sat_df[5000:]) 
vv_pred  = model.predict(vv_df[2000:]) 
si_pred  = model.predict(sig_df[15000:])

# %%
plt.figure(figsize=(10,10))
plt.tick_params(axis="y", labelsize=14)
plt.tick_params(axis="x", labelsize=14)
plt.hist(tt_pred, bins=15, alpha=0.3, label='ttbar')
plt.hist(si_pred, bins=15, alpha=0.3, label='SUSY Mstop 227.5 Mchi 60')
plt.hist(st_pred, bins=15, alpha=0.3, label='Single Top')
plt.hist(vv_pred, bins=15, alpha=0.3, label='Diboson ')
#plt.hist(sat_pred, bins=15, alpha=0.3, label='Single Antitop')
plt.yscale('log')
plt.xlim(0,1)
plt.xlabel('DNN score', fontsize=15)
plt.ylabel('Number of events (log scale)', fontsize=15)
plt.grid()
plt.legend(loc='best', fontsize=15)
plt.savefig('DNN score Mstop_227.5 Mchi_60.jpg')

# %%
np.savetxt('Mstop_227_5_mchi_60_SUSY_pred.txt', si_pred)
np.savetxt('Mstop_227_5_mchi_60_tt_pred.txt'  , tt_pred)
np.savetxt('Mstop_227_5_mchi_60_st_pred.txt'  , st_pred)
np.savetxt('Mstop_227_5_mchi_60_sat_pred.txt' , sat_pred)
np.savetxt('Mstop_227_5_mchi_60_vv_pred.txt'  , vv_pred)

# %%
c0 = 'C0'
c1 = 'C1'
plt.figure(figsize=(10,9))
plt.tick_params(axis="y", labelsize=14)
plt.tick_params(axis="x", labelsize=14)
plt.hist(y_pred_train[y_train == 0], bins=15, label='SM Training set', histtype='step', linestyle='solid', linewidth=1.5, density=True, color=c0)
plt.hist(y_pred_test[y_test == 0]  , bins=15, label='SM Test set'    , alpha=0.3, linewidth=1.5, density=True , color=c0)
plt.hist(y_pred_train[y_train == 1], bins=15, label='SUSY Training set', histtype='step' , linestyle='solid', linewidth=1.5, density=True, color=c1)
plt.hist(y_pred_test[y_test == 1]  , bins=15, label='SUSY Test set ', alpha=0.3, linewidth=1.5, density=True, color=c1)

plt.yscale('log')
plt.ylim(0.1, 40)
plt.xlim(0,1)
plt.xlabel('DNN score (Mstop_227.5 Mchi_60)', fontsize=17)
plt.ylabel('Arbitrary units', fontsize=17)
plt.legend(loc='upper center', fontsize=17)
#plt.savefig('Train vs test Mstop_227.5 Mchi_60.jpg')

# %%
def CorrMtx(df, dropDuplicates = True):

    # Your dataset is already a correlation matrix.
    # If you have a dateset where you need to include the calculation
    # of a correlation matrix, just uncomment the line below:
    # df = df.corr()
    sns.set(font_scale=1.4)
    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(15, 12))

    # Add diverging colormap from red to blue
    #cmap = sns.diverging_palette(250, 10, as_cmap=True)
    #cmap  = sns.color_palette("coolwarm")
    cmap = sns.diverging_palette(0,255,sep=1, as_cmap=True)
                                 
    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        hm = sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax, vmin=-1, vmax=1)
        plt.title('Correlation matrix for input features', fontsize=30)
        plt.savefig('ip_features_corr.png')
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax, vmin=-1, vmax=1)

# %%
CorrMtx(corr, dropDuplicates = True)

# %%
w0 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_0.txt')
w1 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_1.txt')
w2 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_2.txt')
w3 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_3.txt')
w4 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_4.txt')
w6 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_6.txt')
w8 = np.loadtxt('Weights/SUSY/Mstop_227_5/Renorm/Renorm_variation_8.txt')

# %%
llbar_dphi = sig_df['llbar_dphi']

# %%
plt.figure(figsize=(10,9))
plt.tick_params(axis="y", labelsize=14)
plt.tick_params(axis="x", labelsize=14)
#plt.hist(llbar_dphi, bins=15, label='W0', histtype='step', linewidth=1.5, weights=w0)
plt.hist(llbar_dphi, bins=15, label='W1', histtype='step', linewidth=1.5, weights=w1)
plt.hist(llbar_dphi, bins=15, label='W2', histtype='step', linewidth=1.5, weights=w2)
plt.hist(llbar_dphi, bins=15, label='W3', histtype='step', linewidth=1.5, weights=w3)
plt.hist(llbar_dphi, bins=15, label='W4', histtype='step', linewidth=1.5, weights=w4)
plt.hist(llbar_dphi, bins=15, label='W6', histtype='step', linewidth=1.5, weights=w6)
plt.hist(llbar_dphi, bins=15, label='W8', histtype='step', linewidth=1.5, weights=w8)
plt.xlabel('llbar dphi SUSY', fontsize=17)
plt.ylabel('Arbitrary units', fontsize=17)
plt.legend(loc='upper center', fontsize=17)

# %%
print(w0)
print(w1)
# Out:
# [1. 1. 1. ... 1. 1. 1.]
# [0.11588 0.11588 0.11588 ... 0.11552 0.11552 0.11552]

# %%
w0 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_0.txt')
w1 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_1.txt')
w2 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_2.txt')
w3 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_3.txt')
w4 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_4.txt')
w6 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_6.txt')
w8 = np.loadtxt('Weights/ST/Renorm/Renorm_variation_8.txt')

# %%
st_llbar_dphi = st_df['llbar_dphi']

# %%
plt.figure(figsize=(10,9))
plt.tick_params(axis="y", labelsize=14)
plt.tick_params(axis="x", labelsize=14)
plt.hist(st_llbar_dphi, bins=15, label='W0', histtype='step', linewidth=1.5, weights=w0)
plt.hist(st_llbar_dphi, bins=15, label='W1', histtype='step', linewidth=1.5, weights=w1)
plt.hist(st_llbar_dphi, bins=15, label='W2', histtype='step', linewidth=1.5, weights=w2)
plt.hist(st_llbar_dphi, bins=15, label='W3', histtype='step', linewidth=1.5, weights=w3)
plt.hist(st_llbar_dphi, bins=15, label='W4', histtype='step', linewidth=1.5, weights=w4)
plt.hist(st_llbar_dphi, bins=15, label='W6', histtype='step', linewidth=1.5, weights=w6)
plt.hist(st_llbar_dphi, bins=15, label='W8', histtype='step', linewidth=1.5, weights=w8)
plt.xlabel('llbar dphi single top', fontsize=17)
plt.ylabel('Arbitrary units', fontsize=17)
plt.legend(loc='upper center', fontsize=17)

# %%
print(w0)
print(w1)
# Out:
# [42.61399841 41.91999817 42.55400085 ... 43.27099991 42.23600006
#  41.63600159]
# [42.05699921 45.19499969 43.65299988 ... 43.65299988 44.49700165
#  45.95700073]
