# %%
import uproot
import numpy as np
import mplhep as hep
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /var/folders/hq/wz3ys_692nz1g45jvnd49g_r0000gn/T/matplotlib-2wdr8cok because the default path (/Users/bakshi3/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
x = np.random.uniform(0, 10, 240)
y = np.random.normal(512, 112, 240)
z = np.random.normal(0.5, 0.1, 240)

plt.style.use([hep.style.ROOT, hep.style.firamath])

f, ax = plt.subplots()
ax.scatter(x, y, c=z, label="XSX")
hep.cms.label(label='Projection', lumi=30, loc=0)

plt.show()

# %%
fileptr = uproot.open('HEPData-ins1893826.root')
graph   = fileptr['Figure 9a (expected upper limit)']['Graph2D_y1;1']
X       = graph.member('fX')
Y       = graph.member('fY')
Z       = graph.member('fZ')

# %%
mass_pts = [[145 , 1],
[155 , 10],
[155 , 1],
[165 , 10],
[165 , 1],
[165 , 20],
[175 , 10],
[175 , 1],
[175 , 20],
[175 , 30],
[185 , 10],
[185 , 1],
[185 , 20],
[185 , 30],
[185 , 40],
[195 , 10],
[195 , 1],
[195 , 20],
[195 , 30],
[195 , 40],
[195 , 50],
[205 , 10],
[205 , 1],
[205 , 20],
[205 , 30],
[205 , 40],
[205 , 50],
[205 , 60],
[215 , 10],
[215 , 20],
[215 , 30],
[215 , 40],
[215 , 50],
[215 , 60],
[215 , 70],
[225 , 20],
[225 , 30],
[225 , 40],
[225 , 50],
[225 , 60],
[225 , 70],
[225 , 80],
[235 , 30],
[235 , 40],
[235 , 50],
[235 , 60],
[235 , 70],
[235 , 80],
[235 , 90],
[245 , 100],
[245 , 40],
[245 , 50],
[245 , 60],
[245 , 70],
[245 , 80],
[245 , 90],
[255 , 100],
[255 , 50],
[255 , 60],
[255 , 70],
[255 , 80],
[255 , 90],
[265 , 100],
[265 , 60],
[265 , 70],
[265 , 80],
[265 , 90],
[275 , 100],
[275 , 70],
[275 , 80],
[275 , 90],
[285 , 100],
[285 , 80],
[285 , 90],
[295 , 90],] 
# [300 , 105],
# [300 , 115],
# [300 , 125],
# [300 , 135],
# [300 , 145],
# [300 , 155],
# [300 , 95],
# [350 , 145],
# [350 , 155],
# [350 , 165],
# [350 , 175],
# [350 , 185],
# [350 , 195],
# [350 , 205],
# [400 , 195],
# [400 , 205],
# [400 , 215],
# [400 , 225],
# [400 , 235],
# [400 , 245],
# [400 , 255],
# [450 , 245],
# [450 , 255],
# [450 , 265],
# [450 , 275],
# [450 , 285],
# [450 , 295],
# [450 , 305],
# [500 , 295],
# [500 , 305],
# [500 , 315],
# [500 , 325],
# [500 , 335],
# [500 , 345],
# [500 , 355],
# [550 , 345],
# [550 , 355],
# [550 , 365],
# [550 , 375],
# [550 , 385],
# [550 , 395],
# [550 , 405],
# [600 , 395],
# [600 , 405],
# [600 , 415],
# [600 , 425],
# [600 , 435],
# [600 , 445],
# [600 , 455],
# [650 , 445],
# [650 , 455],
# [650 , 465],
# [650 , 475],
# [650 , 485],
# [650 , 495],
# [650 , 505],
# [700 , 495],
# [700 , 505],
# [700 , 515],
# [700 , 525],
# [700 , 535],
# [700 , 545],
# [700 , 555],
# [750 , 545],
# [750 , 555],
# [750 , 565],
# [750 , 575],
# [750 , 585],
# [750 , 595],
# [750 , 605],
# [800 , 595],
# [800 , 605],
# [800 , 615],
# [800 , 625],
# [800 , 635],
# [800 , 645],
# [800 , 655],
# [850 , 645],
# [850 , 655],
# [850 , 665],
# [850 , 675],
# [850 , 685],
# [850 , 695],
# [850 , 705],
# [900 , 695],
# [900 , 705],
# [900 , 715],
# [900 , 725],
# [900 , 735],
# [900 , 745],
# [900 , 755]]

# %%
reduced_X = []
reduced_Y = []
reduced_Z = []

for x,y,z in zip(X,Y,Z) :
    if not [x,y] in mass_pts : continue
    reduced_X.append(x)
    reduced_Y.append(y)
    reduced_Z.append(z)

# %%
f, ax = plt.subplots(figsize=(14,10))
cm = plt.cm.get_cmap('RdYlBu')
sc = plt.scatter(reduced_X, reduced_Y, c=reduced_Z, s=150, cmap=cm)
plt.colorbar(sc)
hep.cms.label(loc=0, data=True, com=13)
plt.show()

# %%
xlabel = r"$m(\tilde{t}_{1}) \ $[GeV]"
ylabel = r"$m(\tilde{\chi}^{0}_{1})\ $[GeV]"
processLabel = r"$pp \rightarrow \tilde{t}_{1}\tilde{t}_{1}, \tilde{t}_{1}\rightarrow t \tilde{\chi}^{0}_{1}"

# %%
two_sig_dict = {(145, 1): 0.5335862396927069, (155, 1): 0.4035252181284192, (155, 10): 0.4731706952757179, (165, 1): 0.3171249783151561, (165, 10): 0.3818483615681512, (165, 20): 0.49644400802839866, (175, 1): 0.21437442746646215, (175, 10): 0.30208492117213637, (175, 20): 0.378396791479839, (175, 30): 0.5196884719751791, (185, 1): 0.2132496424488627, (185, 10): 0.2420475014039332, (185, 20): 0.31127624659855485, (185, 30): 0.470287180872508, (185, 40): 0.6855061163194478, (195, 1): 0.199971594760457, (195, 10): 0.21292731063595954, (195, 20): 0.2254102722476686, (195, 30): 0.44645126576349137, (195, 40): 0.5595477938971016, (195, 50): 0.7660728081462438, (205, 1): 0.17918435607660368, (205, 10): 0.198110408797428, (205, 20): 0.22589411632536768, (205, 30): 0.35313769277115353, (205, 40): 0.4482923702029511, (205, 50): 0.614427567932289, (205, 60): 0.8088290988393126, (215, 10): 0.2057958990568125, (215, 20): 0.29147549706367404, (215, 30): 0.31102519390499195, (215, 40): 0.3542072803775082, (215, 50): 0.505513896927936, (215, 60): 0.6552067685255315, (215, 70): 0.8674188845059835, (225, 20): 0.2624678190937266, (225, 30): 0.2948816729639657, (225, 40): 0.3567708387617022, (225, 50): 0.40424662965629254, (225, 60): 0.5407719445405529, (225, 70): 0.7164760596826673, (225, 80): 0.9895095695815981, (235, 30): 0.29210949697857724, (235, 40): 0.3394102236
, (255, 90): 0.7676797831077128, (265, 100): 1.0045216898042708, (265, 60): 0.41327912098076197, (265, 70): 0.46084924487490203, (265, 80): 0.5318771523255854, (265, 90): 0.6373337520924612, (275, 100): 0.7873150235554203, (275, 70): 0.4701943486160598, (275, 80): 0.5247106924466788, (275, 90): 0.6053364080190657, (285, 100): 0.7364236424267292, (285, 80): 0.5155302210822701, (285, 90): 0.5759205653369426, (295, 90): 0.5641237963233142}

# %%
f, ax = plt.subplots(figsize=(16,10))

mstop = [ms for (ms, _ )  in two_sig_dict.keys()]
mchi0 = [mc for ( _, mc ) in two_sig_dict.keys()]
upper = [v  for v  in two_sig_dict.values()]

# Generate heat map
cm = plt.cm.get_cmap('RdYlBu')
sc  = plt.scatter(mstop, mchi0, c=upper, s=400, cmap=cm, marker='s')
clb = plt.colorbar()
clb.set_label('95% upper limit on cross section [pb]', labelpad= 20, y=0.9, rotation=90)
hep.cms.label(loc=0, label='Phase 2 Projection Prelimary', data=True, com=14)

# Axis Labels
hep.atlas.set_xlabel(xlabel)
hep.atlas.set_ylabel(ylabel)
plt.show()

# %%
f, ax = plt.subplots(figsize=(16,10))

mstop = [ms for (ms, _ )  in two_sig_dict.keys()]
mchi0 = [mc for ( _, mc ) in two_sig_dict.keys()]
upper = [v  for v  in two_sig_dict.values()]

# import scipy.interpolate
# # Interpolate 
# rbf = scipy.interpolate.Rbf(mstop, mchi0, upper, function='linear')
# upper = rbf(mstop, mchi0)

# Generate heat map
cm = plt.cm.get_cmap('RdYlBu')
sc  = plt.scatter(mstop, mchi0, c=upper, s=400, cmap=cm, marker='s')
clb = plt.colorbar()
clb.set_label('95% upper limit on cross section [pb]', labelpad= 20, y=0.9, rotation=90)
hep.cms.label(loc=0, label='Phase 2 Projection Prelimary', data=True, com=14)

# Axis Labels
hep.atlas.set_xlabel(xlabel)
hep.atlas.set_ylabel(ylabel)
plt.show()

# %%
xsec_limit_dict = {}
for x,y,z in zip(reduced_X, reduced_Y, reduced_Z) :
    xsec_limit_dict[(x,y)]  = z

# %%
ratio_dict = {}
for ms, mc in zip(mstop, mchi0) :
    run2      = xsec_limit_dict[(ms,mc)]
    projected = two_sig_dict[(ms,mc)] 
    ratio_dict[(ms,mc)] = (run2/projected)

# %%
mstop = [ms for (ms, _ )  in ratio_dict.keys()]
mchi0 = [mc for ( _, mc ) in ratio_dict.keys()]
upper = [v  for v  in ratio_dict.values()]

f, ax = plt.subplots(figsize=(16,10))
cm = plt.cm.get_cmap('RdYlBu')
sc = plt.scatter(mstop, mchi0, c=ratio, s=400, cmap=cm, marker='s')
clb = plt.colorbar()
clb.set_label('Ratio of limits (Projected / Run2)', labelpad= 20, y=0.85, rotation=90)
hep.cms.label(loc=0, label='Phase 2 Projection Preliminary', data=True, com=14)

## Axis Labels
hep.atlas.set_xlabel(xlabel)
hep.atlas.set_ylabel(ylabel)
plt.show()
